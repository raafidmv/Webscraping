# %%
import requests
from bs4 import BeautifulSoup

# Function to scrape movie data from a single page
def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find movie information
    movies = []
    for movie in soup.find_all('div', class_='movie'):
        movie_name = movie.find('h2').text.strip()
        year = movie.find('span', class_='year').text.strip()
        rating = movie.find('span', class_='rating').text.strip()
        
        # Append movie data to the list
        movies.append({'movie_name': movie_name, 'year': year, 'rating': rating})
    
    return movies

# Main function to scrape multiple pages of movie data
def scrape_multiple_pages(base_url, num_pages=10):
    all_movies = []
    for page in range(1, num_pages+1):
        url = f"{base_url}?page={page}"  # Construct URL for each page
        movies_on_page = scrape_page(url)
        all_movies.extend(movies_on_page)
    
    return all_movies

if __name__ == "__main__":
    base_url = 'https://malayalamsubtitles.org/'  # Replace with the actual URL of the movie website
    
    # Scrape up to 10 pages of movie data
    movie_data = scrape_multiple_pages(base_url, num_pages=10)
    
    # Print the scraped movie data
    for movie in movie_data:
        print(movie)

# %%
import requests
from bs4 import BeautifulSoup
import time

def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    movie_entries = soup.find_all(class_='entry-title-link')
    movie_data = []

    for entry in movie_entries:
        movie_name = entry.text.strip()
        movie_data.append(movie_name)

    return movie_data

def scrape_multiple_pages(base_url, num_pages):
    all_movie_data = []
    current_page = 1

    while current_page <= num_pages:
        url = f"{base_url}/{current_page}/"
        movie_data = scrape_page(url)
        all_movie_data.extend(movie_data)
        print(f"Scraped page {current_page}")
        time.sleep(2)
        current_page += 1

    return all_movie_data

def main():
    base_url = 'https://malayalamsubtitles.org/page'
    num_pages = 5

    movie_data = scrape_multiple_pages(base_url, num_pages)

    for i, movie in enumerate(movie_data, start=1):
        print(f"{i}. {movie}")

if __name__ == "__main__":
    main()
# Out:
# Scraped page 1
# Scraped page 2
# Scraped page 3
# Scraped page 4
# Scraped page 5
# 1. Always: Sunset on Third Street / ഓൾവേസ്: സൺസെറ്റ് ഓൺ തേഡ് സ്ട്രീറ്റ് (2005)
# 2. Postman to Heaven / പോസ്റ്റ്മാൻ ടു ഹെവൻ (2009)
# 3. Indiana Jones and the Kingdom of the Crystal Skull / ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ കിങ്ഡം ഓഫ് ദ ക്രിസ്റ്റൽ സ്കൾ (2008)
# 4. Indiana Jones and the Last Crusade / ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ ലാസ്റ്റ് ക്രൂസേഡ് (1989)
# 5. Indiana Jones and the Temple of Doom / ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ ടെമ്പിൾ ഓഫ് ഡൂം (1984)
# 6. Indiana Jones and the Raiders of the Lost Ark / ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്ക് (1981)
# 7. Damsel / ഡാംസെൽ (2024)
# 8. Perfect Days / പെർഫക്റ്റ് ഡേയ്സ് (2023)
# 9. The Walking Dead: The Ones Who Live Season 1 / ദ വാക്കിങ് ഡെഡ്: ദ വൺസ് ഹു ലിവ് സീസൺ 1 (2024)
# 10. The Third Murder / ദ തേഡ് മർഡർ (2017)
# 11. Fallen Leaves / ഫോളൻ ലീവ്സ് (2023)
# 12. Ozark Season 4 / ഒസാർക് സീസൺ 4 (2022)
# 13. Lupin III: The Castle of Cagliostro / ലൂപാന്‍ III: ദ കാസില്‍ ഓഫ് കാഗ്ലിയോസ്ട്രോ (1979)
# 14. Death’s Game [K-Drama] / ഡെത്ത്സ് ഗെയിം [കെ-ഡ്രാമ] (2023)
# 15. Mune: Guardian of the Moon / മ്യൂൺ: ഗാർഡിയൻ ഓഫ് ദ മൂൺ (2014)
# 16. OMG 2 / ഓ എം ജി 2 (2023)
# 17. Killers of the Flower Moon / കില്ലേഴ് ഓഫ് ദ ഫ്ലവ‌ർ മൂൺ (2023)
# 18. Io Capitano / ഈയോ കപിതാനോ (2023)
# 19. Vigilante Season 1 / വിജിലാന്റി സീസൺ 1 (2023)
# 20. The Bridge Curse / ദ ബ്രിഡ്ജ് കേഴ്സ് (2020)
# 21. The Walking Dead – Season 11 / ദ വാക്കിങ് ഡെഡ് – സീസൺ 11 (2021)
# 22. Y Tu Mamá También / യി തു മമാ തമ്പിയെൻ (2001)
# 23. City Hunter / സിറ്റി ഹണ്ടർ (1993)
# 24. Concrete Utopia / കോൺക്രീറ്റ് ഉട്ടോപ്യ (2023)
# 25. Badland Hunters / ബാഡ്‌ലാൻഡ് ഹണ്ടേഴ്‌സ് (2024)
# 26. Anatomy of a Fall / അനാട്ടമി ഓഫ് എ ഫോൾ (2023)
# 27. A Piece of Your Mind [K-Drama] / എ പീസ് ഓഫ് യുവർ മൈൻഡ് [കെ-ഡ്രാമ] (2020)
# 28. Sex Is Zero 2 / സെക്സ് ഈസ് സീറോ 2 (2007)
# 29. The Harvest / ദ ഹാർവെസ്റ്റ് (2013)
# 30. Antique / ആൻ്റിക് (2008)
# 31. Normal People [Miniseries] / നോർമൽ പീപ്പിൾ [മിനി സീരീസ്‍ (2020)
# 32. 12th Fail / 12ത് ഫെയിൽ (2023)
# 33. One Piece Season 1 / വൺ പീസ് സീസൺ 1 (2023)
# 34. Switch / സ്വിച്ച് (2023)
# 35. God’s Crooked Lines / ഗോഡ്സ് ക്രൂക്കഡ് ലൈൻസ് (2022)
# 36. A Haunting in Venice / എ ഹോണ്ടിങ് ഇൻ വെനീസ് (2023)
# 37. Smugglers / സ്മഗ്ലേഴ്സ് (2023)
# 38. Oppenheimer / ഓപ്പന്‍ഹൈമര്‍ (2023)
# 39. The Crimes That Bind / ദ ക്രൈംസ് ദാറ്റ് ബൈൻഡ് (2018)
# 40. The crossing / ദ ക്രോസിങ് (2020)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    movie_entries = soup.find_all(class_='entry-title-link')
    other_data = []  # Add other data fields here

    for entry in movie_entries:
        movie_name = entry.text.strip()
        other_data.append(movie_name)

    # Add scraping logic for other elements or classes here

    return other_data

def scrape_multiple_pages(base_url, num_pages):
    all_movie_data = []
    current_page = 1

    while current_page <= num_pages:
        url = f"{base_url}/{current_page}/"
        movie_data = scrape_page(url)
        all_movie_data.extend(movie_data)
        print(f"Scraped page {current_page}")
        time.sleep(2)
        current_page += 1

    return all_movie_data

def main():
    base_url = 'https://malayalamsubtitles.org/page'
    num_pages = 5

    movie_data = scrape_multiple_pages(base_url, num_pages)

    df = pd.DataFrame(movie_data, columns=['Movie Name'])  # Adjust column names as needed
    df.to_excel('movie_data.xlsx', index=False)
    print("Data saved to movie_data.xlsx")

if __name__ == "__main__":
    main()
# Out:
# /Users/raafid_mv/Documents/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Scraped page 1
# Scraped page 2
# Scraped page 3
# Scraped page 4
# Scraped page 5
# Data saved to movie_data.xlsx

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Print out the links
    for link in links:
        print(link.get('href'))
else:
    print('Failed to retrieve the webpage.')
# Out:
# #genesis-nav-primary
# #genesis-content
# #genesis-footer-widgets
# https://malayalamsubtitles.org/
# https://malayalamsubtitles.org/translations/
# https://malayalamsubtitles.org/category/genre/web-series/
# https://malayalamsubtitles.org/advanced-filter/
# https://malayalamsubtitles.org/subtitle-download-count/
# https://malayalamsubtitles.org/audience/
# https://malayalamsubtitles.org/msonesubeditor/
# https://malayalamsubtitles.org/writeups/
# https://malayalamsubtitles.org/explanations/
# https://malayalamsubtitles.org/%e0%b4%8e%e0%b4%82%e0%b4%b8%e0%b5%8b%e0%b5%ba-%e0%b4%ab%e0%b5%86%e0%b4%b8%e0%b5%8d%e0%b4%b1%e0%b5%8d%e0%b4%b1%e0%b5%81%e0%b4%95%e0%b5%be-04/
# https://malayalamsubtitles.org/category/malayalamhi/
# https://malayalamsubtitles.org/send/
# https://malayalamsubtitles.org/freshers-submission/
# https://malayalamsubtitles.org/subtitle-status/
# https://malayalamsubtitles.org/msonetranslators/
# https://malayalamsubtitles.org/about/
# https://malayalamsubtitles.org/languages/japanese/always-sunset-on-third-street-2005/
# https://malayalamsubtitles.org/languages/japanese/always-sunset-on-third-street-2005/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/languages/korean/postman-to-heaven-2009/
# https://malayalamsubtitles.org/languages/korean/postman-to-heaven-2009/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-kingdom-of-the-crystal-skull-2008/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-kingdom-of-the-crystal-skull-2008/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-last-crusade-1989/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-last-crusade-1989/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-temple-of-doom-1984/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-temple-of-doom-1984/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-raiders-of-the-lost-ark-1981/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-raiders-of-the-lost-ark-1981/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/languages/english/damsel-2024/
# https://malayalamsubtitles.org/languages/english/damsel-2024/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/languages/japanese/perfect-days-2023/
# https://malayalamsubtitles.org/languages/japanese/perfect-days-2023/
# https://malayalamsubtitles.org/author/vishnu-prasad/
# https://malayalamsubtitles.org/
# https://malayalamsubtitles.org/page/2/
# https://malayalamsubtitles.org/page/3/
# https://malayalamsubtitles.org/page/411/
# https://malayalamsubtitles.org/page/2/
# /cdn-cgi/l/email-protection#234e504c4d465056415063444e424a4f0d404c4e
# https://www.facebook.com/MSonePage/
# https://instagram.com/msoneofficial
# /cdn-cgi/l/email-protection
# https://www.malayalamsubtitles.org/
# #
# https://telegram.me/msone

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Filter and sort the links that start with 'https://malayalamsubtitles.org/languages'
    sorted_links = sorted(link.get('href') for link in links if link.get('href', '').startswith('https://malayalamsubtitles.org/languages'))
    
    # Print out the sorted links
    for link in sorted_links:
        print(link)
else:
    print('Failed to retrieve the webpage.')
# Out:
# https://malayalamsubtitles.org/languages/english/damsel-2024/
# https://malayalamsubtitles.org/languages/english/damsel-2024/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-kingdom-of-the-crystal-skull-2008/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-kingdom-of-the-crystal-skull-2008/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-last-crusade-1989/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-last-crusade-1989/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-raiders-of-the-lost-ark-1981/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-raiders-of-the-lost-ark-1981/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-temple-of-doom-1984/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-temple-of-doom-1984/
# https://malayalamsubtitles.org/languages/japanese/always-sunset-on-third-street-2005/
# https://malayalamsubtitles.org/languages/japanese/always-sunset-on-third-street-2005/
# https://malayalamsubtitles.org/languages/japanese/perfect-days-2023/
# https://malayalamsubtitles.org/languages/japanese/perfect-days-2023/
# https://malayalamsubtitles.org/languages/korean/postman-to-heaven-2009/
# https://malayalamsubtitles.org/languages/korean/postman-to-heaven-2009/

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Print out the unique links
    for link in unique_links:
        print(link)
else:
    print('Failed to retrieve the webpage.')
# Out:
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-last-crusade-1989/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-raiders-of-the-lost-ark-1981/
# https://malayalamsubtitles.org/languages/korean/postman-to-heaven-2009/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-kingdom-of-the-crystal-skull-2008/
# https://malayalamsubtitles.org/languages/english/damsel-2024/
# https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-temple-of-doom-1984/
# https://malayalamsubtitles.org/languages/japanese/always-sunset-on-third-street-2005/
# https://malayalamsubtitles.org/languages/japanese/perfect-days-2023/

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Iterate over unique links
    for link in unique_links:
        # Send a GET request to the link
        page_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if page_response.status_code == 200:
            # Parse the HTML content of the page
            page_soup = BeautifulSoup(page_response.content, 'html.parser')
            
            # Find tags containing "wp-block-group__inner-container"
            inner_containers = page_soup.find_all(class_='wp-block-group__inner-container')
            
            # Print out the content of each inner container
            for container in inner_containers:
                print(container.text)
        else:
            print(f'Failed to retrieve webpage: {link}')
else:
    print('Failed to retrieve the webpage.')
# Out:
# എംസോൺ റിലീസ് – 216
# MSONE GOLD RELEASE
# പോസ്റ്റർ : ഉണ്ണി ജയേഷ്
# ഭാഷഇംഗ്ലീഷ്സംവിധാനംSteven Spielbergപരിഭാഷവിഷ്ണു പ്രസാദ്ജോണർആക്ഷൻ, അഡ്വഞ്ചർ
#
#
#
#
#
# 8.2/10
#
#
# Download
#
#
#
#
# ഇൻഡിയാന ജോണ്‍സ് ഫ്രാഞ്ചൈസിയിലെ [റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്ക് (1981), ടെമ്പിൾ ഓഫ് ഡൂം (1984)] മൂന്നാമത്തെ പതിപ്പായി 1989-ൽ പുറത്തിറങ്ങിയ സിനിമയാണ് ഇൻഡിയാന ജോണ്‍സ് ആൻഡ് ദ ലാസ്റ്റ് ക്രൂസേഡ്.
# ഒരുനാൾ അമേരിക്കൻ വ്യവസായിയായ വാൾട്ടർ ഡോനവൻ, അമർത്യത നൽകുമെന്ന് പറയപ്പെടുന്ന യേശുക്രിസ്തു അന്ത്യ അത്താഴ വേളയിൽ ഉപയോഗിച്ച പാനപാത്രം സൂക്ഷിച്ച് വെച്ചിരിക്കുന്ന സ്ഥലം കണ്ടുപിടിക്കണമെന്ന് പറഞ്ഞ് അദ്ദേഹത്തെ സമീപിക്കുന്നു. ആദ്യം സമ്മതിക്കാൻ കൂട്ടാക്കാതെ ജോൺസ്‌, തന്റെ പിതാവ് പാനപാത്ര അന്വേഷണത്തിൽ കാണാതായി എന്നറിഞ്ഞതോടെ പിതാവിനെ കണ്ടുപിടിക്കാനും ഒപ്പം ആ പാനപാത്രത്തിന്റെ നിഗൂഢതകൾ തേടിയും പുറപ്പെടുകയാണ്.
# മുൻപുള്ള സിനിമകളിൽ നിന്ന് വ്യത്യസ്തമായി സിനിമയിലെ പ്രധാന കാതൽ, ജോൺസും തന്റെ പിതാവും തമ്മിലുള്ള സങ്കീർണ്ണമായ ബന്ധമാണ്. ആദ്യ ജെയിംസ് ബോണ്ടിനെ അനശ്വരമാക്കിയ ഇതിഹാസതാരം ഷോൺ കോണറിയാണ് ഇൻഡിയാന ജോണ്‍സിന്റെ പിതാവായി വേഷമിട്ടിരിക്കുന്നത്.
# അഭിപ്രായങ്ങൾ പങ്കുവെക്കാൻ
#
#
#
#
#
#
# 8.2/10
#
#
# Download
#
#
#
#
#
# എംസോൺ റിലീസ് – 213
# MSONE GOLD RELEASE
# പോസ്റ്റർ : ഉണ്ണി ജയേഷ്
# ഭാഷഇംഗ്ലീഷ്സംവിധാനംSteven Spielbergപരിഭാഷവിഷ്ണു പ്രസാദ്ജോണർആക്ഷൻ, അഡ്വഞ്ചർ
#
#
#
#
#
# 8.4/10
#
#
# Download
#
#
#
#
# 1981-ൽ ഐക്കോണിക് ഫിലിം മേക്കറായ ജോർജ് ലൂക്കാസ് സൃഷ്ടിച്ച്, ഹാരിസൺ ഫോഡ് ജീവസുറ്റതാക്കി, വിഖ്യാത സംവിധായകൻ സ്റ്റീവൻ സ്പിൽബെർഗ്‌ പടുത്തുയർത്തിയ ഒരു ഫ്രാഞ്ചൈസിയാണ് ഇൻഡിയാന ജോൺസ്‌. നിർഭയനും, വിവേകിയുമായ ഡോക്ടർ ഇൻഡിയാന ജോൺസ്‌ എന്ന പുരാവസ്തുഗവേഷകന്റെ അതി സാഹസിക യാത്രകളാണ് ഇതുവരെ അഞ്ച് ഭാഗങ്ങളായി വ്യാപിച്ചുകിടക്കുന്നത്.
# ഈ പരമ്പരയിലെ ആദ്യ ഭാഗമാണ് “റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ
ക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി
#
#
#
#
#
# 6.1/10
#
#
# Download
#
#
#
#
# മില്ലി ബോബി ബ്രൗണിനെ നായികയാക്കി ജുവാൻ കാർലോസിന്റെ സംവിധാനത്തിൽ 2024-യിൽ നെറ്റ്ഫ്ലിക്സിലൂടെ പുറത്തിറങ്ങിയ അഡ്വഞ്ചർ-ഫാന്റസി ചിത്രമാണ് ഡാംസെൽ.
# ദാരിദ്രത്തിന്റെ അത്യുച്ചത്തിൽ നിൽക്കുന്ന ഒരു രാജ്യത്തിന്റെ രാജകുമാരിയാണ് കഥയിലെ നായികയായ എലോഡി. രാജാവായ അച്ഛനും അനിയത്തിയും രണ്ടാനമ്മയും ഉൾപ്പെടുന്ന കുടുംബമാണ് എലോഡിയുടേത്. രാജ്യത്തെ അഭിവൃദ്ധിയിലേക്ക് കൊണ്ടുവരാൻ മറ്റൊരു മാർഗ്ഗവും കാണാതെ രാജാവ് തന്റെ മകളെ മറ്റൊരു രാജ്യത്തെ രാജകുമാരന് വിവാഹം ചെയ്തു കൊടുക്കുന്നു, സുഖസൗകര്യങ്ങളും മറ്റും പ്രതീക്ഷിച്ചു ആ രാജ്യത്തേക്ക് എത്തിയ നായികയും കുടുംബവും അവിടെ നേരിടേണ്ടി വരുന്നത് തീ-തുപ്പുന്ന ഒരു വ്യാളിയേയും അതിലും അപകടകാരികളായ മനുഷ്യരെയുമാണ്. ഒരു കെട്ടുകഥ പോലെ കണ്ടിരിക്കാവുന്ന ഫാന്റസി ചിത്രമാണ് ഡാംസെൽ.
# അഭിപ്രായങ്ങൾ പങ്കുവെക്കാൻ
#
#
#
#
#
#
# 6.1/10
#
#
# Download
#
#
#
#
#
# എംസോൺ റിലീസ് – 215
# MSONE GOLD RELEASE
# പോസ്റ്റർ : ഉണ്ണി ജയേഷ്
# ഭാഷഇംഗ്ലീഷ്സംവിധാനംSteven Spielbergപരിഭാഷവിഷ്ണു പ്രസാദ്ജോണർആക്ഷൻ, അഡ്വഞ്ചർ
#
#
#
#
#
# 7.5/10
#
#
# Download
#
#
#
#
# “റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്കിന്റെ” വിജയത്തെത്തുടർന്ന് 1984-ൽ പുറത്തിറങ്ങിയ പ്രീക്വൽ ഭാഗമാണ് “ഇൻഡിയാന ജോണ്‍സ് ആൻഡ് ദ ടെമ്പിൾ ഓഫ് ഡൂം” ആദ്യ ചിത്രത്തിലെ സംഭവങ്ങൾക്ക് ഒരു വർഷം മുമ്പ് 1935-ലാണ് കഥ നടക്കുന്നത്.
# ഇത്തവണ ഡോക്ടർ ഇൻഡിയാന ജോൺസിന്റെ സാഹസികതകൾ ഇന്ത്യയിലാണ് അരങ്ങേറുന്നത്. ഒരു വിമാനപകടത്തിൽ നിന്ന് രക്ഷപ്പെടുന്ന ജോൺസും, അദ്ദേഹത്തിന്റെ കുഞ്ഞു സഹായി ഷോർട്ട് റൗണ്ടും, പിന്നെ പാട്ടുകാരിയുമായ വില്ലീ സ്കോട്ടും എത്തിപ്പെടുന്നത് ഇന്ത്യയിലെ ദരിദ്രമായ ഒരു കുഗ്രാമത്തിലോട്ടാണ്. ഭഗവാൻ ശിവൻ അയച്ച ദൂതനായി കണ്ട ജോൺസിനോട് ആ ഗ്രാമവാസികൾ അവിടെ നടക്കുന്ന ദുരിതങ്ങൾ പറഞ്ഞു. തന്

# അഭിപ്രായങ്ങൾ പങ്കുവെക്കാൻ
#
#
#
#
#
#
# 7.7/10
#
#
# Download
#
#
#
#
#
# എംസോൺ റിലീസ് – 3329
# ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09
# പോസ്റ്റർ :  നിഷാദ് ജെ എന്‍
# ഭാഷജാപ്പനീസ്സംവിധാനംWim Wendersപരിഭാഷഎല്‍വിന്‍ ജോണ്‍ പോള്‍ജോണർഡ്രാമ
#
#
#
#
#
# 7.9/10
#
#
# Download
#
#
#
#
# വിം വെന്‍ഡേഴ്സ് എന്ന ജര്‍മന്‍ സംവിധായകന്‍ കോജി യാക്കുഷോയെ മുഖ്യകഥാപാത്രമാക്കി നിര്‍മ്മിച്ച ഒരു ജാപ്പനീസ് ചിത്രമാണ് 2023-ല്‍ പുറത്തിറങ്ങിയ “പെര്‍ഫക്റ്റ്‌ ഡേയ്സ്“.
# ഹിരയാമ എന്ന മധ്യവയസ്സുകാരന് ടോക്കിയോയിലെ പൊതുശുചിമുറികള്‍ വൃത്തിയാക്കുന്നതാണ് ജോലി. വളരെ ലളിതവും, ശാന്തവുമായതാണ് അദ്ദേഹത്തിന്റെ ദൈനംദിന ജീവിതം. ഈ ദൈനംദിന ജീവിതവും അതിനിടയില്‍ അദ്ദേഹം കണ്ടുമുട്ടുന്ന ചില വ്യക്തികളിലൂടെയും, അനുഭവങ്ങളിലൂടെയും അദ്ദേഹം തന്റെ ജീവിതത്തെക്കുറിച്ച് സ്വയം വിലയിരുത്തുന്നതുമാണ് ചിത്രത്തിന്റെ ഇതിവൃത്തം.
# ഐ.എഫ്.എഫ്.കെയില്‍ ഉള്‍പ്പടെ നിരവധി ചലച്ചിത്ര മേളകളില്‍ പ്രദര്‍ശിപ്പിച്ച സിനിമ ഒട്ടേറെ നിരൂപക ശ്രദ്ധ പിടിച്ചു പറ്റി. ചിത്രത്തിലെ പ്രകടനത്തിന് കോജി യാക്കുഷോക്ക് 2023-ലെ കാന്‍ ചലച്ചിത്രമേളയിലെ മികച്ച നടനുള്ള പുരസ്കാരം ലഭിക്കുകയുണ്ടായി. 2024-ലെ ഓസ്കാര്‍ പുരസ്കാരങ്ങളില്‍ മികച്ച വിദേശഭാഷ ചിത്രത്തിനുള്ള നോമിനേഷന്‍ ചിത്രത്തിന് ലഭിക്കുകയുണ്ടായി.
# അഭിപ്രായങ്ങൾ പങ്കുവെക്കാൻ
#
#
#
#
#
#
# 7.9/10
#
#
# Download

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Create lists to store data
    data = {'Link': [], 'Text': []}
    
    # Iterate over unique links
    for link in unique_links:
        # Send a GET request to the link
        page_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if page_response.status_code == 200:
            # Parse the HTML content of the page
            page_soup = BeautifulSoup(page_response.content, 'html.parser')
            
            # Find tags containing "wp-block-group__inner-container"
            inner_containers = page_soup.find_all(class_='wp-block-group__inner-container')
            
            # Store data in lists
            for container in inner_containers:
                data['Link'].append(link)
                data['Text'].append(container.text)
        else:
            print(f'Failed to retrieve webpage: {link}')
else:
    print('Failed to retrieve the webpage.')

# Convert data to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to Excel file
df.to_excel('scraped_data.xlsx', index=False)

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link
        sub_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if sub_response.status_code == 200:
            # Parse the HTML content of the subpage
            sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
            
            # Find the tag containing the specified class attribute
            download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
            
            # Extract data-downloadurl attribute from each tag
            for download_link in download_links:
                data_downloadurl = download_link.get('data-downloadurl')
# https://malayalamsubtitles.org/download/perfect-days-%e0%b4%aa%e0%b5%86%e0%b5%bc%e0%b4%ab%e0%b4%95%e0%b5%8d%e0%b4%b1%e0%b5%8d%e0%b4%b1%e0%b5%8d-%e0%b4%a1%e0%b5%87%e0%b4%af%e0%b5%8d%e0%b4%b8%e0%b5%8d-2023/?wpdmdl=43734&refresh=660d073a4fd9e1712129850

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Initialize a list to store tuples of (URL, data-downloadurl) pairs
    url_data_downloadurls = []
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link
        sub_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if sub_response.status_code == 200:
            # Parse the HTML content of the subpage
            sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
            
            # Find the tag containing the specified class attribute
            download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
            
            # Extract data-downloadurl attribute from each tag
            for download_link in download_links:
                data_downloadurl = download_link.get('data-downloadurl')
                url_data_downloadurls.append((link, data_downloadurl))
        else:
            print(f'Failed to retrieve content from {link}')
else:
    print('Failed to retrieve the webpage.')

# Create a DataFrame with URL and data-downloadurl attributes
df = pd.DataFrame(url_data_downloadurls, columns=['URL', 'data-downloadurl'])

# Print the DataFrame
print(df)
# Out:
#                                                  URL  \
# 0  https://malayalamsubtitles.org/languages/engli...
# 1  https://malayalamsubtitles.org/languages/engli...
# 2  https://malayalamsubtitles.org/languages/korea...
# 3  https://malayalamsubtitles.org/languages/engli...
# 4  https://malayalamsubtitles.org/languages/engli...
# 5  https://malayalamsubtitles.org/languages/engli...
# 6  https://malayalamsubtitles.org/languages/japan...
# 7  https://malayalamsubtitles.org/languages/japan...
#
#                                     data-downloadurl
# 0  https://malayalamsubtitles.org/download/indian...
# 1  https://malayalamsubtitles.org/download/indian...
# 2  https://malayalamsubtitles.org/download/postma...
# 3  https://malayalamsubtitles.org/download/indian...
# 4  https://malayalamsubtitles.org/download/damsel...
# 5  https://malayalamsubtitles.org/download/indian...
# 6  https://malayalamsubtitles.org/download/always...
# 7  https://malayalamsubtitles.org/download/perfec...

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Loop through each unique link
    for link in unique_links:
        # Send a GET request to the individual link
        response_link = requests.get(link)
        
        # Check if the request was successful
        if response_link.status_code == 200:
            # Parse the HTML content of the individual page
            soup_link = BeautifulSoup(response_link.content, 'html.parser')
            
            # Find the meta tag with property="og:description"
            meta_tag = soup_link.find('meta', property='og:description')
            
            # Extract the content attribute of the meta tag
            if meta_tag:
                description_content = meta_tag.get('content')
                print(f"Description for {link}: {description_content}")
            else:
                print(f"No meta tag found for {link}")
        else:
            print(f"Failed to retrieve the webpage: {link}")
else:
    print('Failed to retrieve the main webpage.')
# Out:
# Description for https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-last-crusade-1989/: എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steven Spielberg പരിഭാഷ വിഷ്ണു പ്രസാദ് ജോണർ ആക്ഷൻ, അഡ്വഞ്ചർ 8.2/10 ഇൻഡിയാന ജോണ്‍സ് ഫ്രാഞ്ചൈസിയിലെ [റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്ക് (1981), ടെമ്പിൾ ഓഫ് ഡൂം (1984)] മൂന്നാമത്തെ പതിപ്പായി 1989-ൽ പുറത്തിറങ്ങിയ സിനിമയാണ് ഇൻഡിയാന ജോണ്‍സ് ആൻഡ് ദ ലാസ്റ്റ് ക്രൂസേഡ്. ഒരുനാൾ അമേരിക്കൻ വ്യവസായിയായ വാൾട്ടർ ഡോനവൻ, അമർത്യത നൽകുമെന്ന് പറയപ്പെടുന്ന യേശുക്രിസ്തു അന്ത്യ അത്താഴ വേളയിൽ […]
# Description for https://malayalamsubtitles.org/languages/english/indiana-jones-and-the-raiders-of-the-lost-ark-1981/: എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steven Spielberg പരിഭാഷ വിഷ്ണു പ്രസാദ് ജോണർ ആക്ഷൻ, അഡ്വഞ്ചർ
െയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്കിന്റെ” വിജയത്തെത്തുടർന്ന് 1984-ൽ പുറത്തിറങ്ങിയ പ്രീക്വൽ ഭാഗമാണ് “ഇൻഡിയാന ജോണ്‍സ് ആൻഡ് ദ ടെമ്പിൾ ഓഫ് ഡൂം” ആദ്യ ചിത്രത്തിലെ സംഭവങ്ങൾക്ക് ഒരു വർഷം മുമ്പ് 1935-ലാണ് കഥ നടക്കുന്നത്. ഇത്തവണ ഡോക്ടർ ഇൻഡിയാന ജോൺസിന്റെ സാഹസികതകൾ ഇന്ത്യയിലാണ് അരങ്ങേറുന്നത്. ഒരു വിമാനപകടത്തിൽ നിന്ന് […]
# Description for https://malayalamsubtitles.org/languages/japanese/always-sunset-on-third-street-2005/: എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Takashi Yamazaki പരിഭാഷ സുബീഷ് ചിറ്റാരിപ്പറമ്പ്. ജോണർ കോമഡി, ഡ്രാമ, ഫാമിലി 7.7/10 താകാഷി യാമസാക്കി സംവിധാനം ചെയ്ത് 2005-ൽ പുറത്തിറങ്ങിയ ഒരു സൂപ്പർഹിറ്റ് ജാപ്പനീസ് ചലച്ചിത്രമാണ് “ഓൾവേസ്: സൺസെറ്റ് ഓൺ തേഡ് സ്ട്രീറ്റ്. “ രണ്ടാം ലോക മഹായുദ്ധത്തിന് ശേഷം പതിയെ ജീവിതം തിരിച്ചു പിടിക്കുന്ന ജപ്പാൻ ജനതയുടെ അതിജീവനത്തിന്റെ കഥ കൂടിയാണ് ഈ ചിത്രത്തിലൂടെ സംവിധായകൻ പ്രേക്ഷകർക്ക് മുന്നിൽ കോറിയിട്ടത്. 2006-ലെ ഏറ്റവും മികച്ച […]
# Description for https://malayalamsubtitles.org/languages/japanese/perfect-days-2023/: എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ഭാഷ ജാപ്പനീസ് സംവിധാനം Wim Wenders പരിഭാഷ എല്‍വിന്‍ ജോണ്‍ പോള്‍ ജോണർ ഡ്രാമ 7.9/10 വിം വെന്‍ഡേഴ്സ് എന്ന ജര്‍മന്‍ സംവിധായകന്‍ കോജി യാക്കുഷോയെ മുഖ്യകഥാപാത്രമാക്കി നിര്‍മ്മിച്ച ഒരു ജാപ്പനീസ് ചിത്രമാണ് 2023-ല്‍ പുറത്തിറങ്ങിയ “പെര്‍ഫക്റ്റ്‌ ഡേയ്സ്“. ഹിരയാമ എന്ന മധ്യവയസ്സുകാരന് ടോക്കിയോയിലെ പൊതുശുചിമുറികള്‍ വൃത്തിയാക്കുന്നതാണ് ജോലി. വളരെ ലളിതവും, ശാന്തവുമായതാണ് അദ്ദേഹത്തിന്റെ ദൈനംദിന ജീവിതം. ഈ ദൈനംദിന ജീവിതവും അതിനിടയില്‍ അദ്ദേഹം കണ്ടുമുട്ടുന്ന ചില […]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Initialize a list to store tuples of (URL, data-downloadurl, description) pairs
    url_data_downloadurls_description = []
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link
        sub_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if sub_response.status_code == 200:
            # Parse the HTML content of the subpage
            sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
            
            # Find the tag containing the specified class attribute
            download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
            
            # Extract data-downloadurl attribute from each tag
            for download_link in download_links:
                data_downloadurl = download_link.get('data-downloadurl')
                
                # Find the meta tag with property="og:description"
                meta_tag = sub_soup.find('meta', property='og:description')
                description_content = meta_tag.get('content') if meta_tag else None
                
                url_data_downloadurls_description.append((link, data_downloadurl, description_content))
        else:
            print(f'Failed to retrieve content from {link}')
else:
    print('Failed to retrieve the webpage.')

# Create a DataFrame with URL, data-downloadurl, and description attributes
df = pd.DataFrame(url_data_downloadurls_description, columns=['URL', 'data-downloadurl', 'description'])

# Print the DataFrame
print(df)
# Out:
#                                                  URL  \
# 0  https://malayalamsubtitles.org/languages/engli...
# 1  https://malayalamsubtitles.org/languages/engli...
# 2  https://malayalamsubtitles.org/languages/korea...
# 3  https://malayalamsubtitles.org/languages/engli...
# 4  https://malayalamsubtitles.org/languages/engli...
# 5  https://malayalamsubtitles.org/languages/engli...
# 6  https://malayalamsubtitles.org/languages/japan...
# 7  https://malayalamsubtitles.org/languages/japan...
#
#                                     data-downloadurl  \
# 0  https://malayalamsubtitles.org/download/indian...
# 1  https://malayalamsubtitles.org/download/indian...
# 2  https://malayalamsubtitles.org/download/postma...
# 3  https://malayalamsubtitles.org/download/indian...
# 4  https://malayalamsubtitles.org/download/damsel...
# 5  https://malayalamsubtitles.org/download/indian...
# 6  https://malayalamsubtitles.org/download/always...
# 7  https://malayalamsubtitles.org/download/perfec...
#
#                                          description
# 0  എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 1  എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 2  എംസോൺ റിലീസ് – 3331 ഭാഷ കൊറിയൻ സംവിധാനം Lee Hy...
# 3  എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...
# 4  എംസോൺ റിലീസ് – 3330 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Juan...
# 5  എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 6  എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Taka...
# 7  എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Initialize a list to store tuples of (URL, data-downloadurl, og:description, og:image) pairs
    url_data_downloadurls_description = []
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link
        sub_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if sub_response.status_code == 200:
            # Parse the HTML content of the subpage
            sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
            
            # Find the tag containing the specified class attribute
            download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
            
            # Extract data-downloadurl attribute from each tag
            for download_link in download_links:
                data_downloadurl = download_link.get('data-downloadurl')
                
                # Find the meta tags with properties="og:description" and "og:image"
                og_description_tag = sub_soup.find('meta', property='og:description')
                og_image_tag = sub_soup.find('meta', property='og:image')
                
                og_description_content = og_description_tag.get('content') if og_description_tag else None
                og_image_content = og_image_tag.get('content') if og_image_tag else None
                
                url_data_downloadurls_description.append((link, data_downloadurl, og_description_content, og_image_content))
        else:
            print(f'Failed to retrieve content from {link}')
else:
    print('Failed to retrieve the webpage.')

# Create a DataFrame with URL, data-downloadurl, og:description, and og:image attributes
df = pd.DataFrame(url_data_downloadurls_description, columns=['URL', 'data-downloadurl', 'og:description', 'og:image'])

# Print the DataFrame
print(df)
# Out:
#                                                  URL  \
# 0  https://malayalamsubtitles.org/languages/engli...
# 1  https://malayalamsubtitles.org/languages/engli...
# 2  https://malayalamsubtitles.org/languages/korea...
# 3  https://malayalamsubtitles.org/languages/engli...
# 4  https://malayalamsubtitles.org/languages/engli...
# 5  https://malayalamsubtitles.org/languages/engli...
# 6  https://malayalamsubtitles.org/languages/japan...
# 7  https://malayalamsubtitles.org/languages/japan...
#
#                                     data-downloadurl  \
# 0  https://malayalamsubtitles.org/download/indian...
# 1  https://malayalamsubtitles.org/download/indian...
# 2  https://malayalamsubtitles.org/download/postma...
# 3  https://malayalamsubtitles.org/download/indian...
# 4  https://malayalamsubtitles.org/download/damsel...
# 5  https://malayalamsubtitles.org/download/indian...
# 6  https://malayalamsubtitles.org/download/always...
# 7  https://malayalamsubtitles.org/download/perfec...
#
#                                       og:description  \
# 0  എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 1  എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 2  എംസോൺ റിലീസ് – 3331 ഭാഷ കൊറിയൻ സംവിധാനം Lee Hy...
# 3  എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...
# 4  എംസോൺ റിലീസ് – 3330 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Juan...
# 5  എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 6  എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Taka...
# 7  എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ...
#
#                                             og:image
# 0  https://malayalamsubtitles.org/wp-content/uplo...
# 1  https://malayalamsubtitles.org/wp-content/uplo...
# 2  https://malayalamsubtitles.org/wp-content/uplo...
# 3  https://malayalamsubtitles.org/wp-content/uplo...
# 4  https://malayalamsubtitles.org/wp-content/uplo...
# 5  https://malayalamsubtitles.org/wp-content/uplo...
# 6  https://malayalamsubtitles.org/wp-content/uplo...
# 7  https://malayalamsubtitles.org/wp-content/uplo...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Initialize a list to store tuples of (URL, data-downloadurl, og:description, og:image) pairs
    url_data_downloadurls_description = []
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link
        sub_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if sub_response.status_code == 200:
            # Parse the HTML content of the subpage
            sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
            
            # Find the tag containing the specified class attribute
            download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
            
            # Extract data-downloadurl attribute from each tag
            for download_link in download_links:
                data_downloadurl = download_link.get('data-downloadurl')
                
                # Find the meta tags with properties="og:description" and "og:image"
                og_description_tag = sub_soup.find('meta', property='og:description')
                og_image_tag = sub_soup.find('meta', property='og:image')
                
                og_description_content = og_description_tag.get('content') if og_description_tag else None
                og_image_content = og_image_tag.get('content') if og_image_tag else None
                
                url_data_downloadurls_description.append((link, data_downloadurl, og_description_content, og_image_content))
        else:
            print(f'Failed to retrieve content from {link}')
else:
    print('Failed to retrieve the webpage.')

# Create a DataFrame with URL, data-downloadurl, og:description, and og:image attributes
df = pd.DataFrame(url_data_downloadurls_description, columns=['URL', 'data-downloadurl', 'og:description', 'og:image'])

# Save the DataFrame to an Excel file
df.to_excel('scraped_data.xlsx', index=False)

print("Data has been saved to 'scraped_data.xlsx'")
# Out:
# Data has been saved to 'scraped_data.xlsx'

# %%
import pandas as pd

# Sample data
data = {'Description': ['എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steven Spielberg പരിഭാഷ വിഷ്ണു പ്രസാദ് ജോണർ ആക്ഷൻ, അഡ്വഞ്ചർ 6.2/10 ഇൻഡിയാന ജോൺസ് ഫ്രാഞ്ചൈസിയിലെ [റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്ക് (1981), ടെമ്പിൾ ഓഫ് ഡൂം (1984), ലാസ്റ്റ് ക്രൂസേഡ് (1989)] നാലാമത്തെ പതിപ്പാണ് 2008-ൽ പുറത്തിറങ്ങിയ ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ കിങ്ഡം ഓഫ് ദ ക്രിസ്റ്റൽ സ്കൾ. നീണ്ട 19 വർഷങ്ങൾക്ക് ശേഷം സ്റ്റീവൻ സ്പീൽബർഗും, ജോർജ് ലൂക്കാസും ഹാരിസൺ ഫോഡും […]']}

# Create DataFrame
df = pd.DataFrame(data)

# Define regex pattern for splitting the text
pattern = r'(.*?) ഭാഷ (.*?) സംവിധാനം (.*?) പരിഭാഷ (.*)'

# Split the text into separate columns
df[['Column1', 'Column2', 'Column3', 'Column4']] = df['Description'].str.extract(pattern)

# Drop the original 'Description' column
df.drop(columns=['Description'], inplace=True)

# Print the resulting DataFrame
print(df)
# Out:
#               Column1   Column2           Column3  \
# 0  എംസോൺ റിലീസ് – 217  ഇംഗ്ലീഷ്  Steven Spielberg
#
#                                              Column4
# 0  വിഷ്ണു പ്രസാദ് ജോണർ ആക്ഷൻ, അഡ്വഞ്ചർ 6.2/10 ഇൻഡ...

# %%
import pandas as pd
import re

# Sample data
data = {'text': ['എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steven Spielberg പരിഭാഷ വിഷ്ണു പ്രസാദ് ജോണർ ആക്ഷൻ, അഡ്വഞ്ചർ 6.2/10 ഇൻഡിയാന ജോൺസ് ഫ്രാഞ്ചൈസിയിലെ [റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്ക് (1981), ടെമ്പിൾ ഓഫ് ഡൂം (1984), ലാസ്റ്റ് ക്രൂസേഡ് (1989)] നാലാമത്തെ പതിപ്പാണ് 2008-ൽ പുറത്തിറങ്ങിയ ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ കിങ്ഡം ഓഫ് ദ ക്രിസ്റ്റൽ സ്കൾ. നീണ്ട 19 വർഷങ്ങൾക്ക് ശേഷം സ്റ്റീവൻ സ്പീൽബർഗും, ജോർജ് ലൂക്കാസും ഹാരിസൺ ഫോഡും […']
}

# Create DataFrame
df = pd.DataFrame(data)

# Function to extract parts of the text using regular expressions
def extract_parts(text):
    match = re.match(r'(.*?)\sഭാഷ\s(.*?)\sസംവിധാനം\s(.*?)\sപരിഭാഷ\s(.*?)\sജോണർ\s(.*)', text)
    if match:
        return match.groups()
    else:
        return (None, None, None, None, None)
    match = re.search(r'(\d\.\d)/10', text)
    if match:
        return match.group(1) + "/10"
    else:
        return None
        
    match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
    if match:
        return match.group(1)
    else:
        return None

# Apply the function to the 'text' column and create a new column
df['director_to_rating'] = df['text'].apply(extract_text)


# Apply the function to the 'text' column and create a new column
df['rating'] = df['text'].apply(extract_rating)

# Apply the function to the 'text' column and expand it into separate columns
df[['Column1', 'Column2', 'Column3', 'Column4', 'Column5']] = df['text'].apply(lambda x: pd.Series(extract_parts(x)))

# Display the DataFrame
print(df)
# Out:
#                                                 text director_to_rating  \
# 0  എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...    ആക്ഷൻ, അഡ്വഞ്ചർ
#
#    rating             Column1   Column2           Column3         Column4  \
# 0  6.2/10  എംസോൺ റിലീസ് – 217  ഇംഗ്ലീഷ്  Steven Spielberg  വിഷ്ണു പ്രസാദ്
#
#                                              Column5
# 0  ആക്ഷൻ, അഡ്വഞ്ചർ 6.2/10 ഇൻഡിയാന ജോൺസ് ഫ്രാഞ്ചൈസ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Initialize a list to store tuples of (URL, data-downloadurl, description) pairs
    url_data_downloadurls_description = []
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link
        sub_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if sub_response.status_code == 200:
            # Parse the HTML content of the subpage
            sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
            
            # Find the tag containing the specified class attribute
            download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
            
            # Extract data-downloadurl attribute from each tag
            for download_link in download_links:
                data_downloadurl = download_link.get('data-downloadurl')
                
                # Find the meta tags with property="og:description", "og:image", and "og:title"
                og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
                og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
                og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None
                
                url_data_downloadurls_description.append((link, data_downloadurl, og_description, og_image, og_title))
        else:
            print(f'Failed to retrieve content from {link}')
else:
    print('Failed to retrieve the webpage.')

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, and og:title attributes
df = pd.DataFrame(url_data_downloadurls_description, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title'])

# Print the DataFrame
print(df)
# Out:
#                                                  URL  \
# 0  https://malayalamsubtitles.org/languages/engli...
# 1  https://malayalamsubtitles.org/languages/engli...
# 2  https://malayalamsubtitles.org/languages/korea...
# 3  https://malayalamsubtitles.org/languages/engli...
# 4  https://malayalamsubtitles.org/languages/engli...
# 5  https://malayalamsubtitles.org/languages/engli...
# 6  https://malayalamsubtitles.org/languages/japan...
# 7  https://malayalamsubtitles.org/languages/japan...
#
#                                     data-downloadurl  \
# 0  https://malayalamsubtitles.org/download/indian...
# 1  https://malayalamsubtitles.org/download/indian...
# 2  https://malayalamsubtitles.org/download/postma...
# 3  https://malayalamsubtitles.org/download/indian...
# 4  https://malayalamsubtitles.org/download/damsel...
# 5  https://malayalamsubtitles.org/download/indian...
# 6  https://malayalamsubtitles.org/download/always...
# 7  https://malayalamsubtitles.org/download/perfec...
#
#                                       og:description  \
# 0  എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 1  എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 2  എംസോൺ റിലീസ് – 3331 ഭാഷ കൊറിയൻ സംവിധാനം Lee Hy...
# 3  എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...
# 4  എംസോൺ റിലീസ് – 3330 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Juan...
# 5  എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 6  എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Taka...
# 7  എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ...
#
#                                             og:image  \
# 0  https://malayalamsubtitles.org/wp-content/uplo...
# 1  https://malayalamsubtitles.org/wp-content/uplo...
# 2  https://malayalamsubtitles.org/wp-content/uplo...
# 3  https://malayalamsubtitles.org/wp-content/uplo...
# 4  https://malayalamsubtitles.org/wp-content/uplo...
# 5  https://malayalamsubtitles.org/wp-content/uplo...
# 6  https://malayalamsubtitles.org/wp-content/uplo...
# 7  https://malayalamsubtitles.org/wp-content/uplo...
#
#                                             og:title
# 0  Indiana Jones and the Last Crusade / ഇൻഡിയാന ജ...
# 1  Indiana Jones and the Raiders of the Lost Ark ...
# 2  Postman to Heaven / പോസ്റ്റ്മാൻ ടു ഹെവൻ (2009)...
# 3  Indiana Jones and the Kingdom of the Crystal S...
# 4                     Damsel / ഡാംസെൽ (2024) - എംസോൺ
# 5  Indiana Jones and the Temple of Doom / ഇൻഡിയാന...
# 6  Always: Sunset on Third Street / ഓൾവേസ്: സൺസെറ...
# 7    Perfect Days / പെർഫക്റ്റ് ഡേയ്സ് (2023) - എംസോൺ

# %%
import pandas as pd
import re

# Sample data
data = {'text': ['എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steven Spielberg പരിഭാഷ വിഷ്ണു പ്രസാദ് ജോണർ ആക്ഷൻ, അഡ്വഞ്ചർ 6.2/10 ഇൻഡിയാന ജോൺസ് ഫ്രാഞ്ചൈസിയിലെ [റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ് ആർക്ക് (1981), ടെമ്പിൾ ഓഫ് ഡൂം (1984), ലാസ്റ്റ് ക്രൂസേഡ് (1989)] നാലാമത്തെ പതിപ്പാണ് 2008-ൽ പുറത്തിറങ്ങിയ ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ കിങ്ഡം ഓഫ് ദ ക്രിസ്റ്റൽ സ്കൾ. നീണ്ട 19 വർഷങ്ങൾക്ക് ശേഷം സ്റ്റീവൻ സ്പീൽബർഗും, ജോർജ് ലൂക്കാസും ഹാരിസൺ ഫോഡും […']
}

# Create DataFrame
df = pd.DataFrame(data)

# Function to extract the desired text
def extract_text(text):
    match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
    if match:
        return match.group(1)
    else:
        return None

# Apply the function to the 'text' column and create a new column
df['director_to_rating'] = df['text'].apply(extract_text)

# Display the DataFrame
print(df)
# Out:
#                                                 text director_to_rating
# 0  എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...    ആക്ഷൻ, അഡ്വഞ്ചർ

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Define the URL of the website to scrape
url = 'https://malayalamsubtitles.org/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Initialize a list to store tuples of (URL, data-downloadurl, og:description, og:image, og:title) pairs
    url_data_downloadurls_description = []
    
    # Function to extract parts of the text using regular expressions
    def extract_parts(text):
        match = re.match(r'(.*?)\sഭാഷ\s(.*?)\sസംവിധാനം\s(.*?)\sപരിഭാഷ\s(.*?)\sജോണർ\s(.*)', text)
        if match:
            return match.groups()
        else:
            return (None, None, None, None, None)

    # Function to extract the rating
    def extract_rating(text):
        match = re.search(r'(\d\.\d)/10', text)
        if match:
            return match.group(1) + "/10"
        else:
            return None
        
    # Function to extract director name
    def extract_director(text):
        match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
        if match:
            return match.group(1)
        else:
            return None
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link
        sub_response = requests.get(link)
        
        # Check if the request was successful (status code 200)
        if sub_response.status_code == 200:
            # Parse the HTML content of the subpage
            sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
            
            # Find the tag containing the specified class attribute
            download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
            
            # Extract data-downloadurl attribute from each tag
            for download_link in download_links:
                data_downloadurl = download_link.get('data-downloadurl')
                
                # Find the meta tags with property="og:description", "og:image", and "og:title"
                og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
                og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
                og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None
                
                url_data_downloadurls_description.append((link, data_downloadurl, og_description, og_image, og_title))
        else:
            print(f'Failed to retrieve content from {link}')
else:
    print('Failed to retrieve the webpage.')

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, and og:title attributes
df = pd.DataFrame(url_data_downloadurls_description, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title'])

# Add the 'director_to_rating' column
df['director_to_rating'] = df['og:description'].apply(extract_director)

# Add the 'rating' column
df['rating'] = df['og:description'].apply(extract_rating)

# Apply the function to the 'og:description' column and expand it into separate columns
df[['Column1', 'Column2', 'Column3', 'Column4', 'Column5']] = df['og:description'].apply(lambda x: pd.Series(extract_parts(x)))

# Print the DataFrame
print(df)
# Out:
#                                                  URL  \
# 0  https://malayalamsubtitles.org/languages/engli...
# 1  https://malayalamsubtitles.org/languages/engli...
# 2  https://malayalamsubtitles.org/languages/korea...
# 3  https://malayalamsubtitles.org/languages/engli...
# 4  https://malayalamsubtitles.org/languages/engli...
# 5  https://malayalamsubtitles.org/languages/engli...
# 6  https://malayalamsubtitles.org/languages/japan...
# 7  https://malayalamsubtitles.org/languages/japan...
#
#                                     data-downloadurl  \
# 0  https://malayalamsubtitles.org/download/indian...
# 1  https://malayalamsubtitles.org/download/indian...
# 2  https://malayalamsubtitles.org/download/postma...
# 3  https://malayalamsubtitles.org/download/indian...
# 4  https://malayalamsubtitles.org/download/damsel...
# 5  https://malayalamsubtitles.org/download/indian...
# 6  https://malayalamsubtitles.org/download/always...
# 7  https://malayalamsubtitles.org/download/perfec...
#
#                                       og:description  \
# 0  എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 1  എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 2  എംസോൺ റിലീസ് – 3331 ഭാഷ കൊറിയൻ സംവിധാനം Lee Hy...
# 3  എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...
# 4  എംസോൺ റിലീസ് – 3330 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Juan...
# 5  എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 6  എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Taka...
# 7  എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ...
#
#                                             og:image  \
# 0  https://malayalamsubtitles.org/wp-content/uplo...
# 1  https://malayalamsubtitles.org/wp-content/uplo...
# 2  https://malayalamsubtitles.org/wp-content/uplo...
# 3  https://malayalamsubtitles.org/wp-content/uplo...
# 4  https://malayalamsubtitles.org/wp-content/uplo...
# 5  https://malayalamsubtitles.org/wp-content/uplo...
# 6  https://malayalamsubtitles.org/wp-content/uplo...
# 7  https://malayalamsubtitles.org/wp-content/uplo...
#
#                                             og:title  \
# 0  Indiana Jones and the Last Crusade / ഇൻഡിയാന ജ...
# 1  Indiana Jones and the Raiders of the Lost Ark ...
# 2  Postman to Heaven / പോസ്റ്റ്മാൻ ടു ഹെവൻ (2009)...
# 3  Indiana Jones and the Kingdom of the Crystal S...
# 4                     Damsel / ഡാംസെൽ (2024) - എംസോൺ
# 5  Indiana Jones and the Temple of Doom / ഇൻഡിയാന...
# 6  Always: Sunset on Third Street / ഓൾവേസ്: സൺസെറ...
# 7    Perfect Days / പെർഫക്റ്റ് ഡേയ്സ് (2023) - എംസോൺ
#
#          director_to_rating  rating  \
# 0           ആക്ഷൻ, അഡ്വഞ്ചർ  8.2/10
# 1           ആക്ഷൻ, അഡ്വഞ്ചർ  8.4/10
# 2  ഡ്രാമ, ഫാന്റസി, റൊമാൻസ്  6.6/10
# 3           ആക്ഷൻ, അഡ്വഞ്ചർ  6.2/10
# 4  ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി  6.1/10
# 5           ആക്ഷൻ, അഡ്വഞ്ചർ  7.5/10
# 6      കോമഡി, ഡ്രാമ, ഫാമിലി  7.7/10
# 7                     ഡ്രാമ  7.9/10
#
#                                          Column1    Column2  \
# 0          എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE   ഇംഗ്ലീഷ്
# 1          എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE   ഇംഗ്ലീഷ്
# 2                            എംസോൺ റിലീസ് – 3331     കൊറിയൻ
# 3                             എംസോൺ റിലീസ് – 217   ഇംഗ്ലീഷ്
# 4                            എംസോൺ റിലീസ് – 3330   ഇംഗ്ലീഷ്
# 5          എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE   ഇംഗ്ലീഷ്
# 6                             എംസോൺ റിലീസ് – 887  ജാപ്പനീസ്
# 7  എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09  ജാപ്പനീസ്
#
#                    Column3                   Column4  \
# 0         Steven Spielberg            വിഷ്ണു പ്രസാദ്
# 1         Steven Spielberg            വിഷ്ണു പ്രസാദ്
# 2           Lee Hyeong-min            അരവിന്ദ് കുമാർ
# 3         Steven Spielberg            വിഷ്ണു പ്രസാദ്
# 4  Juan Carlos Fresnadillo             ഗിരി പി. എസ്.
# 5         Steven Spielberg            വിഷ്ണു പ്രസാദ്
# 6         Takashi Yamazaki  സുബീഷ് ചിറ്റാരിപ്പറമ്പ്.
# 7              Wim Wenders     എല്‍വിന്‍ ജോണ്‍ പോള്‍
#
#                                              Column5
# 0  ആക്ഷൻ, അഡ്വഞ്ചർ 8.2/10 ഇൻഡിയാന ജോണ്‍സ് ഫ്രാഞ്ച...
# 1  ആക്ഷൻ, അഡ്വഞ്ചർ 8.4/10 1981-ൽ ഐക്കോണിക് ഫിലിം ...
# 2  ഡ്രാമ, ഫാന്റസി, റൊമാൻസ് 6.6/10 കൊറിയൻ ആരാധകരു...
# 3  ആക്ഷൻ, അഡ്വഞ്ചർ 6.2/10 ഇൻഡിയാന ജോൺസ് ഫ്രാഞ്ചൈസ...
# 4  ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി 6.1/10 മില്ലി ബോബി ബ്...
# 5  ആക്ഷൻ, അഡ്വഞ്ചർ 7.5/10 “റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ...
# 6  കോമഡി, ഡ്രാമ, ഫാമിലി 7.7/10 താകാഷി യാമസാക്കി സ...
# 7  ഡ്രാമ 7.9/10 വിം വെന്‍ഡേഴ്സ് എന്ന ജര്‍മന്‍ സംവ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Define the base URL of the website to scrape
base_url = 'https://malayalamsubtitles.org/page/'

# Define the number of pages to scrape
num_pages = 5

# Initialize a list to store all scraped data
all_data = []

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f'{base_url}{page_number}/'
    
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract specific information from the page
        # For example, let's extract all the links on the page
        links = soup.find_all('a')
        
        # Set to store unique links
        unique_links = set()
        
        # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
        for link in links:
            href = link.get('href', '')
            if href.startswith('https://malayalamsubtitles.org/languages'):
                unique_links.add(href)
        
        # Iterate through unique links and scrape desired information
        for link in unique_links:
            # Send a GET request to the link
            sub_response = requests.get(link)
            
            # Check if the request was successful (status code 200)
            if sub_response.status_code == 200:
                # Parse the HTML content of the subpage
                sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
                
                # Find the tag containing the specified class attribute
                download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
                
                # Extract data-downloadurl attribute from each tag
                for download_link in download_links:
                    data_downloadurl = download_link.get('data-downloadurl')
                    
                    # Find the meta tags with property="og:description", "og:image", and "og:title"
                    og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
                    og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
                    og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None
                    
                    all_data.append((link, data_downloadurl, og_description, og_image, og_title))
            else:
                print(f'Failed to retrieve content from {link}')
    else:
        print(f'Failed to retrieve the webpage: {url}')

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, and og:title attributes
df = pd.DataFrame(all_data, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title'])

# Print the DataFrame
print(df)
# Out:
#                                                   URL  \
# 0   https://malayalamsubtitles.org/languages/engli...
# 1   https://malayalamsubtitles.org/languages/engli...
# 2   https://malayalamsubtitles.org/languages/korea...
# 3   https://malayalamsubtitles.org/languages/engli...
# 4   https://malayalamsubtitles.org/languages/engli...
# 5   https://malayalamsubtitles.org/languages/engli...
# 6   https://malayalamsubtitles.org/languages/japan...
# 7   https://malayalamsubtitles.org/languages/japan...
# 8   https://malayalamsubtitles.org/languages/japan...
# 9   https://malayalamsubtitles.org/languages/hindi...
# 10  https://malayalamsubtitles.org/languages/engli...
# 11  https://malayalamsubtitles.org/languages/japan...
# 12  https://malayalamsubtitles.org/languages/korea...
# 13  https://malayalamsubtitles.org/languages/frenc...
# 14  https://malayalamsubtitles.org/languages/engli...
# 15  https://malayalamsubtitles.org/languages/finni...
# 16  https://malayalamsubtitles.org/languages/engli...
# 17  https://malayalamsubtitles.org/languages/canto...
# 18  https://malayalamsubtitles.org/languages/engli...
# 19  https://malayalamsubtitles.org/languages/wolof...


# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Define the base URL of the website to scrape
base_url = 'https://malayalamsubtitles.org/page/'

# Define the number of pages to scrape
num_pages = 5

# Initialize a list to store all scraped data
all_data = []

# Function to extract parts of the text using regular expressions
def extract_parts(text):
    match = re.match(r'(.*?)\sഭാഷ\s(.*?)\sസംവിധാനം\s(.*?)\sപരിഭാഷ\s(.*?)\sജോണർ\s(.*)', text)
    if match:
        return match.groups()
    else:
        return (None, None, None, None, None)

# Function to extract rating
def extract_rating(text):
    match = re.search(r'(\d\.\d)/10', text)
    if match:
        return match.group(1) + "/10"
    else:
        return None

# Function to extract director name
def extract_director(text):
    match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
    if match:
        return match.group(1)
    else:
        return None

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f'{base_url}{page_number}/'
    
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract specific information from the page
        # For example, let's extract all the links on the page
        links = soup.find_all('a')
        
        # Set to store unique links
        unique_links = set()
        
        # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
        for link in links:
            href = link.get('href', '')
            if href.startswith('https://malayalamsubtitles.org/languages'):
                unique_links.add(href)
        
        # Iterate through unique links and scrape desired information
        for link in unique_links:
            # Send a GET request to the link
            sub_response = requests.get(link)
            
            # Check if the request was successful (status code 200)
            if sub_response.status_code == 200:
                # Parse the HTML content of the subpage
                sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
                
                # Find the tag containing the specified class attribute
                download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
                
                # Extract data-downloadurl attribute from each tag
                for download_link in download_links:
                    data_downloadurl = download_link.get('data-downloadurl')
                    
                    # Find the meta tags with property="og:description", "og:image", and "og:title"
                    og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
                    og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
                    og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None
                    
                    all_data.append((link, data_downloadurl, og_description, og_image, og_title))
            else:
                print(f'Failed to retrieve content from {link}')
    else:
        print(f'Failed to retrieve the webpage: {url}')

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, and og:title attributes
df = pd.DataFrame(all_data, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title'])

# Add the 'director_to_rating' column
df['director_to_rating'] = df['og:description'].apply(extract_director)

# Add the 'rating' column
df['rating'] = df['og:description'].apply(extract_rating)

# Apply the function to the 'og:description' column and expand it into separate columns
df[['Column1', 'Column2', 'Column3', 'Column4', 'Column5']] = df['og:description'].apply(lambda x: pd.Series(extract_parts(x)))

# Print the DataFrame
print(df)
# Out:
#                                                   URL  \
# 0   https://malayalamsubtitles.org/languages/engli...
# 1   https://malayalamsubtitles.org/languages/engli...
# 2   https://malayalamsubtitles.org/languages/engli...
# 3   https://malayalamsubtitles.org/languages/engli...
# 4   https://malayalamsubtitles.org/languages/korea...
# 5   https://malayalamsubtitles.org/languages/japan...
# 6   https://malayalamsubtitles.org/languages/engli...
# 7   https://malayalamsubtitles.org/languages/japan...
# 8   https://malayalamsubtitles.org/languages/finni...
# 9   https://malayalamsubtitles.org/languages/hindi...
# 10  https://malayalamsubtitles.org/languages/japan...
# 11  https://malayalamsubtitles.org/languages/frenc...
# 12  https://malayalamsubtitles.org/languages/korea...
# 13  https://malayalamsubtitles.org/languages/engli...
# 14  https://malayalamsubtitles.org/languages/engli...
# 15  https://malayalamsubtitles.org/languages/japan...
# 16  https://malayalamsubtitles.org/languages/manda...
# 17  https://malayalamsubtitles.org/languages/spani...
# 18  https://malayalamsubtitles.org/languages/wolof...
# 19  https://malayalamsubtitles.org/languages/canto...
# 20  https://malayalamsubtitles.org/languages/engli...
# 21  https://malayalamsubtitles.org/languages/korea...
# 22  https://malayalamsubtitles.org/languages/engli...
# 23  https://malayalamsubtitles.org/languages/korea...
# 24  https://malayalamsubtitles.org/languages/engli...
# 25  https://malayalamsubtitles.org/languages/frenc...
# 26  https://malayalamsubtitles.org/languages/korea...
# 27  https://malayalamsubtitles.org/languages/korea...
# 28  https://malayalamsubtitles.org/languages/korea...
# 29  https://malayalamsubtitles.org/languages/hindi...
# 30  https://malayalamsubtitles.org/languages/engli...
# 31  https://malayalamsubtitles.org/languages/engli...
# 32  https://malayalamsubtitles.org/languages/norwe...
ഡ്രാമ, ഫാന്റസി, റൊമാൻസ്  6.6/10
# 5         കോമഡി, ഡ്രാമ, ഫാമിലി  7.7/10
# 6     ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി  6.1/10
# 7                        ഡ്രാമ  7.9/10
# 8                 കോമഡി, ഡ്രാമ  7.4/10
# 9                 കോമഡി, ഡ്രാമ  7.6/10
# 10    ക്രെെം, ഡ്രാമ, മിസ്റ്ററി  6.7/10
# 11  അഡ്വഞ്ചർ, അനിമേഷന്‍, കോമഡി  7.1/10
# 12              ഡ്രാമ, ഫാന്റസി  8.6/10
# 13      ക്രൈം, ഡ്രാമ, ത്രില്ലർ  8.5/10
# 14       ഡ്രാമ, ഹൊറർ, ത്രില്ലർ  8.5/10
# 15  ആക്ഷൻ, അഡ്വഞ്ചർ, അനിമേഷന്‍  7.6/10
# 16  ഹൊറർ, മിസ്റ്ററി, ത്രില്ലർ  5.3/10
# 17                       ഡ്രാമ  7.7/10
# 18                       ഡ്രാമ  7.6/10
# 19        അക്ഷൻ, കോമഡി, ക്രെെം  6.9/10
# 20    ക്രെെം, ഡ്രാമ, ഹിസ്റ്ററി  7.7/10
# 21     ആക്ഷൻ, ക്രെെം, ത്രില്ലർ  7.8/10
# 22       ഡ്രാമ, ഹൊറർ, ത്രില്ലർ  8.1/10
# 23      ആക്ഷൻ, അഡ്വഞ്ചർ, ഡ്രാമ  6.2/10
# 24  ഡ്രാമ, മിസ്റ്ററി, ത്രില്ലർ  6.3/10
# 25     ക്രെെം, ഡ്രാമ, ത്രില്ലർ  7.8/10
# 26       കോമഡി, ഡ്രാമ, റൊമാൻസ്  6.0/10
# 27             കോമഡി, റൊമാൻസ്  7.3/10
# 28       കോമഡി, ഡ്രാമ, റൊമാൻസ്  6.8/10
# 29             ബയോഗ്രഫി, ഡ്രാമ  9.2/10
# 30             ഡ്രാമ, റൊമാൻസ്  8.4/10
# 31      ആക്ഷൻ, അഡ്വഞ്ചർ, കോമഡി  8.4/10
# 32     അഡ്വഞ്ചർ, ഡ്രാമ, ഫാമിലി  6.4/10
# 33                ആക്ഷൻ, ഡ്രാമ  6.3/10
# 34       കോമഡി, ഡ്രാമ, ഫാന്റസി  7.0/10
# 35  ഡ്രാമ, മിസ്റ്ററി, ത്രില്ലർ  7.1/10
# 36  ബയോഗ്രഫി, ഡ്രാമ, ഹിസ്റ്ററി  8.4/10
# 37          ക്രൈം, ഡ്രാമ, ഹൊറർ  6.5/10
# 38         മിസ്റ്ററി, ത്രില്ലർ  7.0/10
#
#                                           Column1             Column2  \
# 0           എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE            ഇംഗ്ലീഷ്
# 1           എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE            ഇംഗ്ലീഷ്
# 2           എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE            ഇംഗ്ലീഷ്
# 3                              എംസോൺ റിലീസ് – 217            ഇംഗ്ലീഷ്
# 4                             എംസോൺ റിലീസ് – 3331              കൊറിയൻ
# 5                              എംസോൺ റിലീസ് – 887           ജാപ്പനീസ്
# 6                             എംസോൺ റിലീസ് – 3330            ഇംഗ്ലീഷ്
# 7   എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09           ജാപ്പനീസ്
# 8                             എംസോൺ റിലീസ് – 3327            ഫിന്നിഷ്
# 9                             എംസോൺ റിലീസ് – 3322              ഹിന്ദി
# 10                            എംസോൺ റിലീസ് – 3328           ജാപ്പനീസ്
# 11                            എംസോൺ റിലീസ് – 3323            ഇംഗ്ലീഷ്
# 12                            എംസോൺ റിലീസ് – 3324              കൊറിയൻ
# 13                                           None                None
# 14                                           None                None
# 15         എംസോൺ റിലീസ് – 3325 MSONE GOLD RELEAS
ുബീഷ് ചിറ്റാരിപ്പറമ്പ്.
# 6                                   ഗിരി പി. എസ്.
# 7                           എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 8                           എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 9                                     സജിൻ.എം.എസ്
# 10                                    വിഷ്ണു ഷാജി
# 11                            ജിതിൻ ജേക്കബ് കോശി
# 12               സജിത്ത് ടി. എസ് & അരവിന്ദ് കുമാർ
# 13                                           None
# 14                                           None
# 15                          എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 16                                      സാരംഗ് പി
# 17                                 വിഷ്ണു പ്രസാദ്
# 18                                മുജീബ് സി പി വൈ
# 19                          എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 20                                     വിഷ് ആസാദ്
# 21                                 അരവിന്ദ് കുമാർ
# 22                                           None
# 23                                     തൗഫീക്ക് എ
# 24                                  അഭിഷേക് പി യു
# 25                                       ഡോ. ജമാൽ
# 26                                സജിത്ത് ടി. എസ്
# 27  അരുൺ അശോകൻ, ശ്രുതി രഞ്ജിത്ത് & അരവിന്ദ് കുമാർ
# 28                                 അരവിന്ദ് കുമാർ
# 29                       വിഷ് ആസാദ് & സജിൻ.എം.എസ്
# 30                          അരുൺ അശോകൻ & ഉദയകൃഷ്ണ
# 31                                           None
# 32                                       ഡോ. ജമാൽ
# 33                                     തൗഫീക്ക് എ
# 34                                സജിത്ത് ടി. എസ്
# 35                                    വിഷ്ണു ഷാജി
# 36                          എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 37                             ഫഹദ് അബ്‍ദുൽ മജീദ്
# 38                                      ആസിഫ് ആസി
#
#                                               Column5
# 0   ആക്ഷൻ, അഡ്വഞ്ചർ 8.2/10 ഇൻഡിയാന ജോണ്‍സ് ഫ്രാഞ്ച...
# 1   ആക്ഷൻ, അഡ്വഞ്ചർ 8.4/10 1981-ൽ ഐക്കോണിക് ഫിലിം ...
# 2   ആക്ഷൻ, അഡ്വഞ്ചർ 7.5/10 “റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ...
# 3   ആക്ഷൻ, അഡ്വഞ്ചർ 6.2/10 ഇൻഡിയാന ജോൺസ് ഫ്രാഞ്ചൈസ...
# 4   ഡ്രാമ, ഫാന്റസി, റൊമാൻസ് 6.6/10 കൊറിയൻ ആരാധകരു...
# 5   കോമഡി, ഡ്രാമ, ഫാമിലി 7.7/10 താകാഷി യാമസാക്കി സ...
# 6   ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി 6.1/10 മില്ലി ബോബി ബ്...
# 7   ഡ്രാമ 7.9/10 വിം വെന്‍ഡേഴ്സ് എന്ന ജര്‍മന്‍ സംവ...
# 8   കോമഡി, ഡ്രാമ 7.4/10 വിഖ്യാത ഫിന്നിഷ് സംവിധായകൻ...
# 9   കോമഡി, ഡ്രാമ 7.6/10 പങ്കജ് ത്രിപാഠി, യാമി ഗൗതം...
# 10  ക്രെെം, ഡ്രാമ, മിസ്റ്ററി 6.7/10 Hirokazu Kore-...
# 11  അഡ്വഞ്ചർ, അനിമേഷന്‍, കോമഡി 7.1/10 സ്വപ്നങ്ങളും...
# 12  ഡ്രാമ, ഫാന്റസി 8.6/10 ജീവിതം മടുത്ത് ആത്മഹത്യ ...
# 13                                               None
# 14                                               None
# 15  ആക്ഷൻ, അഡ്വഞ്ചർ, അനിമേഷന്‍ 7.6/10 വിഖ്യാത ജാപ്...
# 16  ഹൊറർ, മിസ്റ്ററി, ത്രില്ലർ 5.3/10 Lester Shih ...
# 17  ഡ്രാമ 7.7/10 അൽഫോൺസോ ക്വാറോൺ സംവിധാനം ചെയ്ത് 2...
# 18  ഡ്രാമ 7.6/10 Matteo Garrone സംവിധാനം ചെയ്ത് 20...
# 19  അക്ഷൻ, കോമഡി, ക്രെെം 6.9/10 സുക്കാസ ഹോജോയുടെ അ...
# 20  ക്രെെം, ഡ്രാമ, ഹിസ്റ്ററി 7.7/10 മാർട്ടിൻ സ്‌കോ...
# 21  ആക്ഷൻ, ക്രെെം, ത്രില്ലർ 7.8/10 നാഷണൽ പോലീസ് യൂ...
# 22                                               None
# 23  ആക്ഷൻ, അഡ്വഞ്ചർ, ഡ്രാമ 6.2/10 2024-ൽ നെറ്റ്ഫ്ല...
# 24  ഡ്രാമ, മിസ്റ്ററി, ത്രില്ലർ 6.3/10 അച്ഛന്റെയും ...
# 25  ക്രെെം, ഡ്രാമ, ത്രില്ലർ 7.8/10 Justine Triet സ...
# 26  കോമഡി, ഡ്രാമ, റൊമാൻസ് 6.0/10 Yoon Tae Yoon ന്റ...
# 27  കോമഡി, റൊമാൻസ് 7.3/10 തൻ്റെ സ്വന്തം കമ്പനിയുട...
# 28  കോമഡി, ഡ്രാമ, റൊമാൻസ് 6.8/10 കുട്ടിക്കാലത്ത് ത...
# 29  ബയോഗ്രഫി, ഡ്രാമ 9.2/10 വിധു വിനോദ് ചോപ്ര രചനയു...
# 30  ഡ്രാമ, റൊമാൻസ് 8.4/10 ഒരിക്കലും ശ്വാശ്വതമായി ...
# 31                                               None
# 32  അഡ്വഞ്ചർ, ഡ്രാമ, ഫാമിലി 6.4/10 1942-ൽ രണ്ടാം ല...
# 33  ആക്ഷൻ, ഡ്രാമ 6.3/10 എസ്കേപ്പ് ഫ്രം മൊഗഡിഷു (20...
# 34  കോമഡി, ഡ്രാമ, ഫാന്റസി 7.0/10 ജീവിതത്തിൽ ഒരിക്ക...
# 35  ഡ്രാമ, മിസ്റ്ററി, ത്രില്ലർ 7.1/10 ദ ബോഡി (2012...
# 36  ബയോഗ്രഫി, ഡ്രാമ, ഹിസ്റ്ററി 8.4/10 “അമേരിക്കന്‍...
# 37  ക്രൈം, ഡ്രാമ, ഹൊറർ 6.5/10 വിരമിച്ചശേഷം ആരുടെയു...
# 38  മിസ്റ്ററി, ത്രില്ലർ 7.0/10 ഇതേ പേരിൽ തന്നെയുള്...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from IPython.display import display

# Define the base URL of the website to scrape
base_url = 'https://malayalamsubtitles.org/page/'

# Define the number of pages to scrape
num_pages = 2

# Initialize a list to store all scraped data
all_data = []

# Function to extract parts of the text using regular expressions
def extract_parts(text):
    match = re.match(r'(.*?)\sഭാഷ\s(.*?)\sസംവിധാനം\s(.*?)\sപരിഭാഷ\s(.*?)\sജോണർ\s(.*)', text)
    if match:
        return match.groups()
    else:
        return (None, None, None, None, None)

# Function to extract rating
def extract_rating(text):
    match = re.search(r'(\d\.\d)/10', text)
    if match:
        return match.group(1) + "/10"
    else:
        return None

# Function to extract director name
def extract_director(text):
    match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
    if match:
        return match.group(1)
    else:
        return None

# Retry logic
retry_strategy = Retry(
    total=3,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    method_whitelist=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f'{base_url}{page_number}/'
    
    # Send a GET request to the URL with retry logic
    with requests.Session() as session:
        session.mount("https://", adapter)
        try:
            response = session.get(url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Failed to retrieve the webpage: {url}")
            continue
    
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link with retry logic
        with requests.Session() as session:
            session.mount("https://", adapter)
            try:
                sub_response = session.get(link)
                sub_response.raise_for_status()
            except requests.exceptions.RequestException as e:
                print(f"Failed to retrieve content from {link}")
                continue
        
        # Parse the HTML content of the subpage
        sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
        
        # Find the tag containing the specified class attribute
        download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
        
        # Extract data-downloadurl attribute from each tag
        for download_link in download_links:
            data_downloadurl = download_link.get('data-downloadurl')
            
            # Find the meta tags with property="og:description", "og:image", and "og:title"
            og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
            og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
            og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None
            
            all_data.append((link, data_downloadurl, og_description, og_image, og_title))

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, and og:title attributes
df = pd.DataFrame(all_data, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title'])

# Add the 'director_to_rating' column
df['director_to_rating'] = df['og:description'].apply(extract_director)

# Add the 'rating' column
df['rating'] = df['og:description'].apply(extract_rating)

# Apply the function to the 'og:description' column and expand it into separate columns
df[['Column1', 'Column2', 'Column3', 'Column4', 'Column5']] = df['og:description'].apply(lambda x: pd.Series(extract_parts(x)))

# Assuming df is your DataFrame and you want to remove the 'Column5' column
df.drop(columns=['Column5'], inplace=True)

# Print the DataFrame
# print(df)
# Define the desired column order
desired_order = ['Column1','og:title', 'Column2','Column3', 'Column4', 'URL', 'og:image','rating', 'director_to_rating','data-downloadurl', 'og:description']

# Rearrange columns
df = df.reindex(columns=desired_order)

# Rename columns
df = df.rename(columns={'Column1':'release_no','og:title':'title', 'Column2':'language','Column3':'director', 'Column4':'transilated_by', 'URL':'website_link', 'og:image':'poster','rating':'rating', 'director_to_rating':'genre','data-downloadurl':'download_link', 'og:description':'description'})

# Split the 'title' column into two columns
df[['title1', 'title2']] = df['title'].str.split(' / ', expand=True)

# Remove the data after the term '(' in the 'title' column
df['title2'] = df['title2'].str.split('(', n=1).str[0]

# Remove the end part '- എംസോൺ' from every row in the 'title' column
df['title'] = df['title'].str.replace(' - എംസോൺ$', '')

# Remove the term 'എംസോൺ റിലീസ് – ' from every row in the 'release_num' column
df['release_no'] = df['release_no'].str.replace('എംസോൺ റിലീസ് – ', '')

# Extract the data within brackets and put it into a new column
df['year'] = df['title'].str.extract(r'\((\d{4})\)')


# Extract the term after 'languages/' up to the next '/'
df['lang'] = df['website_link'].str.extract(r'/languages/([^/]+)/')

# Remove the 5th column and store it in a variable
column_to_move = df.pop(df.columns[12])
df.insert(1, column_to_move.name, column_to_move)

# Remove the 5th column and store it in a variable
column_to_move = df.pop(df.columns[13])
df.insert(2, column_to_move.name, column_to_move)

# Remove the 5th column and store it in a variable
column_to_move = df.pop(df.columns[13])
df.insert(1, column_to_move.name, column_to_move)

# Remove the 5th column and store it in a variable
column_to_move = df.pop(df.columns[14])
df.insert(5, column_to_move.name, column_to_move)

# Display the DataFrame
display(df)
# Save the DataFrame as an Excel file
excel_file_path = 'malayalamsubtitles_data.xlsx'
df.to_excel(excel_file_path, index=False)
print("Data has been saved to 'scraped_data.xlsx'")
# Out:
# /var/folders/0j/k_c7797n13v3f73bfmht7jym0000gn/T/ipykernel_19145/1395306774.py:43: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(
#                         release_no  \
# 0           216 MSONE GOLD RELEASE
# 1           213 MSONE GOLD RELEASE
# 2           215 MSONE GOLD RELEASE
# 3                              217
# 4                             3331
# 5                              887
# 6                             3330
# 7   3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09
# 8                             3327
# 9                             3322
# 10                            3328
# 11                            3323
# 12                            3324
# 13                            None
# 14                            None
# 15         3325 MSONE GOLD RELEASE
#
#                                                title1  \
# 0                  Indiana Jones and the Last Crusade
# 1       Indiana Jones and the Raiders of the Lost Ark
# 2                Indiana Jones and the Temple of Doom
# 3   Indiana Jones and the Kingdom of the Crystal S...
# 4                                   Postman to Heaven
# 5                      Always: Sunset on Third Street
# 6                                              Damsel
# 7                                        Perfect Days
# 8                                       Fallen Leaves
# 9                                               OMG 2
# 10                                   The Third Murder
# 11                         Mune: Guardian of the Moon
# 12                             Death's Game [K-Drama]
# 13                                     Ozark Season 4
# 14       The Walking Dead: The Ones Who Live Season 1
# 15                Lupin III: The Castle of Cagliostro
#
#                                                title2  year  \
# 0             ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ ലാസ്റ്റ് ക്രൂസേഡ്   1989
# 1   ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ്...  1981
# 2               ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ ടെമ്പിൾ ഓഫ് ഡൂം   1984
# 3   ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ കിങ്ഡം ഓഫ് ദ ക്രിസ്റ്റൽ സ...  2008
# 4                                പോസ്റ്റ്മാൻ ടു ഹെവൻ   2009
# 5                ഓൾവേസ്: സൺസെറ്റ് ഓൺ തേഡ് സ്ട്രീറ്റ്   2005
# 6                                             ഡാംസെൽ   2024
# 7                                  പെർഫക്റ്റ് ഡേയ്സ്   2023
# 8                                        ഫോളൻ ലീവ്സ്   2023
# 9                                          ഓ എം ജി 2   2023
# 10                                       ദ തേഡ് മർഡർ   2017
# 11                          മ്യൂൺ: ഗാർഡിയൻ ഓഫ് ദ മൂൺ   2014
# 12                         ഡെത്ത്സ് ഗെയിം [കെ-ഡ്രാമ]   2023
# 13                                     ഒസാർക് സീസൺ 4   2022
# 14            ദ വാക്കിങ് ഡെഡ്: ദ വൺസ് ഹു ലിവ് സീസൺ 1   2024
# 15         ലൂപാന്‍ III: ദ കാസില്‍ ഓഫ് കാഗ്ലിയോസ്ട്രോ   1979
#
#                                                 title               lang  \
# 0   Indiana Jones and the Last Crusade / ഇൻഡിയാന ജ...            english
# 1   Indiana Jones and the Raiders of the Lost Ark ...            english
# 2   Indiana Jones and the Temple of Doom / ഇൻഡിയാന...            english
# 3   Indiana Jones and the Kingdom of the Crystal S...            english
# 4   Postman to Heaven / പോസ്റ്റ്മാൻ ടു ഹെവൻ (2009)...             korean
# 5   Always: Sunset on Third Street / ഓൾവേസ്: സൺസെറ...           japanese
# 6                      Damsel / ഡാംസെൽ (2024) - എംസോൺ            english
# 7     Perfect Days / പെർഫക്റ്റ് ഡേയ്സ് (2023) - എംസോൺ           japanese
# 8          Fallen Leaves / ഫോളൻ ലീവ്സ് (2023) - എംസോൺ  finnish-languages
# 9                    OMG 2 / ഓ എം ജി 2 (2023) - എംസോൺ              hindi
# 10      The Third Murder / ദ തേഡ് മർഡർ (2017) - എംസോൺ           japanese
# 11  Mune: Guardian of the Moon / മ്യൂൺ: ഗാർഡിയൻ ഓഫ...             french
# 12  Death's Game [K-Drama] / ഡെത്ത്സ് ഗെയിം [കെ-ഡ്...             korean
# 13      Ozark Season 4 / ഒസാർക് സീസൺ 4 (2022) - എംസോൺ            english
# 14  The Walking Dead: The Ones Who Live Season 1 /...            english
# 15  Lupin III: The Castle of Cagliostro / ലൂപാന്‍ ...           japanese
#
#      language                              director  \
# 0    ഇംഗ്ലീഷ്                      Steven Spielberg
# 1    ഇംഗ്ലീഷ്                      Steven Spielberg
# 2    ഇംഗ്ലീഷ്                      Steven Spielberg
# 3    ഇംഗ്ലീഷ്                      Steven Spielberg
# 4      കൊറിയൻ                        Lee Hyeong-min
# 5   ജാപ്പനീസ്                      Takashi Yamazaki
# 6    ഇംഗ്ലീഷ്               Juan Carlos Fresnadillo
# 7   ജാപ്പനീസ്                           Wim Wenders
# 8    ഫിന്നിഷ്                        Aki Kaurismäki
# 9      ഹിന്ദി                              Amit Rai
# 10  ജാപ്പനീസ്                     Kore-eda Hirokazu
# 11   ഇംഗ്ലീഷ്  Alexandre Heboyan & Benoît Philippon
# 12     കൊറിയൻ                         Byung-Hoon Ha
# 13       None                                  None
# 14       None                                  None
# 15  ജാപ്പനീസ്                        Hayao Miyazaki
#
#                       transilated_by  \
# 0                     വിഷ്ണു പ്രസാദ്
# 1                     വിഷ്ണു പ്രസാദ്
# 2                     വിഷ്ണു പ്രസാദ്
# 3                     വിഷ്ണു പ്രസാദ്
# 4                     അരവിന്ദ് കുമാർ
# 5           സുബീഷ് ചിറ്റാരിപ്പറമ്പ്.
# 6                      ഗിരി പി. എസ്.
# 7              എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 8              എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 9                        സജിൻ.എം.എസ്
# 10                       വിഷ്ണു ഷാജി
# 11               ജിതിൻ ജേക്കബ് കോശി
# 12  സജിത്ത് ടി. എസ് & അരവിന്ദ് കുമാർ
# 13                              None
# 14                              None
# 15             എല്‍വിന്‍ ജോണ്‍ പോള്‍
#
#                                          website_link  \
# 0   https://malayalamsubtitles.org/languages/engli...
# 1   https://malayalamsubtitles.org/languages/engli...
# 2   https://malayalamsubtitles.org/languages/engli...
# 3   https://malayalamsubtitles.org/languages/engli...
# 4   https://malayalamsubtitles.org/languages/korea...
# 5   https://malayalamsubtitles.org/languages/japan...
# 6   https://malayalamsubtitles.org/languages/engli...
# 7   https://malayalamsubtitles.org/languages/japan...
# 8   https://malayalamsubtitles.org/languages/finni...
# 9   https://malayalamsubtitles.org/languages/hindi...
# 10  https://malayalamsubtitles.org/languages/japan...
# 11  https://malayalamsubtitles.org/languages/frenc...
# 12  https://malayalamsubtitles.org/languages/korea...
# 13  https://malayalamsubtitles.org/languages/engli...
# 14  https://malayalamsubtitles.org/languages/engli...
# 15  https://malayalamsubtitles.org/languages/japan...
#
#                                                poster  rating  \
# 0   https://malayalamsubtitles.org/wp-content/uplo...  8.2/10
# 1   https://malayalamsubtitles.org/wp-content/uplo...  8.4/10
# 2   https://malayalamsubtitles.org/wp-content/uplo...  7.5/10
# 3   https://malayalamsubtitles.org/wp-content/uplo...  6.2/10
# 4   https://malayalamsubtitles.org/wp-content/uplo...  6.6/10
# 5   https://malayalamsubtitles.org/wp-content/uplo...  7.7/10
# 6   https://malayalamsubtitles.org/wp-content/uplo...  6.1/10
# 7   https://malayalamsubtitles.org/wp-content/uplo...  7.9/10
# 8   https://malayalamsubtitles.org/wp-content/uplo...  7.4/10
# 9   https://malayalamsubtitles.org/wp-content/uplo...  7.6/10
# 10  https://malayalamsubtitles.org/wp-content/uplo...  6.7/10
# 11  https://malayalamsubtitles.org/wp-content/uplo...  7.1/10
# 12  https://malayalamsubtitles.org/wp-content/uplo...  8.6/10
# 13  https://malayalamsubtitles.org/wp-content/uplo...  8.5/10
# 14  https://malayalamsubtitles.org/wp-content/uplo...  8.5/10
# 15  https://malayalamsubtitles.org/wp-content/uplo...  7.6/10
#
#                          genre  \
# 0              ആക്ഷൻ, അഡ്വഞ്ചർ
# 1              ആക്ഷൻ, അഡ്വഞ്ചർ
# 2              ആക്ഷൻ, അഡ്വഞ്ചർ
# 3              ആക്ഷൻ, അഡ്വഞ്ചർ
# 4     ഡ്രാമ, ഫാന്റസി, റൊമാൻസ്
# 5         കോമഡി, ഡ്രാമ, ഫാമിലി
# 6     ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി
# 7                        ഡ്രാമ
# 8                 കോമഡി, ഡ്രാമ
# 9                 കോമഡി, ഡ്രാമ
# 10    ക്രെെം, ഡ്രാമ, മിസ്റ്ററി
# 11  അഡ്വഞ്ചർ, അനിമേഷന്‍, കോമഡി
# 12              ഡ്രാമ, ഫാന്റസി
# 13      ക്രൈം, ഡ്രാമ, ത്രില്ലർ
# 14       ഡ്രാമ, ഹൊറർ, ത്രില്ലർ
# 15  ആക്ഷൻ, അഡ്വഞ്ചർ, അനിമേഷന്‍
#
#                                         download_link  \
# 0   https://malayalamsubtitles.org/download/indian...
# 1   https://malayalamsubtitles.org/download/indian...
# 2   https://malayalamsubtitles.org/download/indian...
# 3   https://malayalamsubtitles.org/download/indian...
# 4   https://malayalamsubtitles.org/download/postma...
# 5   https://malayalamsubtitles.org/download/always...
# 6   https://malayalamsubtitles.org/download/damsel...
# 7   https://malayalamsubtitles.org/download/perfec...
# 8   https://malayalamsubtitles.org/download/fallen...
# 9   https://malayalamsubtitles.org/download/omg-2-...
# 10  https://malayalamsubtitles.org/download/the-th...
# 11  https://malayalamsubtitles.org/download/mune-g...
# 12  https://malayalamsubtitles.org/download/deaths...
# 13  https://malayalamsubtitles.org/download/ozark-...
# 14  https://malayalamsubtitles.org/download/the-wa...
# 15  https://malayalamsubtitles.org/download/lupin-...
#
#                                           description
# 0   എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 1   എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 2   എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 3   എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...
# 4   എംസോൺ റിലീസ് – 3331 ഭാഷ കൊറിയൻ സംവിധാനം Lee Hy...
# 5   എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Taka...
# 6   എംസോൺ റിലീസ് – 3330 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Juan...
# 7   എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ...
# 8   എംസോൺ റിലീസ് – 3327 ഭാഷ ഫിന്നിഷ് സംവിധാനം Aki ...
# 9   എംസോൺ റിലീസ് – 3322 ഭാഷ ഹിന്ദി സംവിധാനം Amit R...
# 10  എംസോൺ റിലീസ് – 3328 ഭാഷ ജാപ്പനീസ് സംവിധാനം Kor...
# 11  എംസോൺ റിലീസ് – 3323 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Alex...
# 12  എംസോൺ റിലീസ് – 3324 ഭാഷ കൊറിയൻ സംവിധാനം Byung-...
# 13  എംസോൺ റിലീസ് – 3299 ഭാഷ ഇംഗ്ലീഷ് നിർമ്മാണം MRC...
# 14  എംസോൺ റിലീസ് – 3326 Episodes 01-05 / എപ്പിസോഡ്...
# 15  എംസോൺ റിലീസ് – 3325 MSONE GOLD RELEASE ഭാഷ ജാപ...
# Data has been saved to 'scraped_data.xlsx'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from IPython.display import display

# Define the base URL of the website to scrape
base_url = 'https://malayalamsubtitles.org/page/'

# Define the number of pages to scrape
num_pages = 5

# Initialize a list to store all scraped data
all_data = []

# Function to extract rating
def extract_rating(text):
    match = re.search(r'(\d\.\d)/10', text)
    if match:
        return match.group(1) + "/10"
    else:
        return None

# Function to extract director name
def extract_director(text):
    match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
    if match:
        return match.group(1)
    else:
        return None

# Function to extract text between "ഭാഷ" and "സംവിധാനം"
def extract_between(text):
    match = re.search(r'ഭാഷ\s(.*?)\sസംവിധാനം', text)
    if match:
        return match.group(1)
    else:
        return None

# Function to extract text between "സംവിധാനം" and "പരിഭാഷ"
def extract_direction_to_translation(text):
    match = re.search(r'സംവിധാനം\s(.*?)\sപരിഭാഷ', text)
    if match:
        return match.group(1)
    else:
        return None

# Function to extract text between "പരിഭാഷ" and "ജോണർ"
def extract_translation_to_director(text):
    match = re.search(r'പരിഭാഷ\s(.*?)\sജോണർ', text)
    if match:
        return match.group(1)
    else:
        return None

# Retry logic
retry_strategy = Retry(
    total=3,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    method_whitelist=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f'{base_url}{page_number}/'
    
    # Send a GET request to the URL with retry logic
    with requests.Session() as session:
        session.mount("https://", adapter)
        try:
            response = session.get(url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Failed to retrieve the webpage: {url}")
            continue
    
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link with retry logic
        with requests.Session() as session:
            session.mount("https://", adapter)
            try:
                sub_response = session.get(link)
                sub_response.raise_for_status()
            except requests.exceptions.RequestException as e:
                print(f"Failed to retrieve content from {link}")
                continue
        
        # Parse the HTML content of the subpage
        sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
        
        # Find the tag containing the specified class attribute
        download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
        
        # Extract data-downloadurl attribute from each tag
        for download_link in download_links:
            data_downloadurl = download_link.get('data-downloadurl')
            
            # Find the meta tags with property="og:description", "og:image", and "og:title"
            og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
            og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
            og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None
            
            all_data.append((link, data_downloadurl, og_description, og_image, og_title))

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, and og:title attributes
df = pd.DataFrame(all_data, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title'])

# Add the 'director_to_rating' column
df['director_to_rating'] = df['og:description'].apply(extract_director)

# Add the 'rating' column
df['rating'] = df['og:description'].apply(extract_rating)

# Apply the function to the 'og:description' column and expand it into separate columns
df[['Language', 'Direction', 'Translation', 'Director', 'Column5']] = df['og:description'].apply(lambda x: pd.Series([extract_between(x), extract_direction_to_translation(x), extract_translation_to_director(x), None, None]))

# Assuming df is your DataFrame and you want to remove the 'Column5' column
df.drop(columns=['Column5'], inplace=True)

# Display the DataFrame
display(df)

# # Save the DataFrame as an Excel file
# excel_file_path = 'malayalamsubtitles_data.xlsx'
# df.to_excel(excel_file_path, index=False)
# print("Data has been saved to 'scraped_data.xlsx'")
# Out:
# /var/folders/0j/k_c7797n13v3f73bfmht7jym0000gn/T/ipykernel_19145/1504233158.py:59: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(
#                                                   URL  \
# 0   https://malayalamsubtitles.org/languages/engli...
# 1   https://malayalamsubtitles.org/languages/engli...
# 2   https://malayalamsubtitles.org/languages/engli...
# 3   https://malayalamsubtitles.org/languages/engli...
# 4   https://malayalamsubtitles.org/languages/korea...
# 5   https://malayalamsubtitles.org/languages/japan...
# 6   https://malayalamsubtitles.org/languages/engli...
# 7   https://malayalamsubtitles.org/languages/japan...
# 8   https://malayalamsubtitles.org/languages/finni...
# 9   https://malayalamsubtitles.org/languages/hindi...
# 10  https://malayalamsubtitles.org/languages/japan...
# 11  https://malayalamsubtitles.org/languages/frenc...
# 12  https://malayalamsubtitles.org/languages/korea...
# 13  https://malayalamsubtitles.org/languages/engli...
# 14  https://malayalamsubtitles.org/languages/engli...
# 33             Smugglers / സ്മഗ്ലേഴ്സ് (2023) - എംസോൺ
# 34                   Switch / സ്വിച്ച് (2023) - എംസോൺ
# 35  God's Crooked Lines / ഗോഡ്സ് ക്രൂക്കഡ് ലൈൻസ് (...
# 36         Oppenheimer / ഓപ്പന്‍ഹൈമര്‍ (2023) - എംസോൺ
# 37  A Haunting in Venice / എ ഹോണ്ടിങ് ഇൻ വെനീസ് (2...
# 38  The Crimes That Bind / ദ ക്രൈംസ് ദാറ്റ് ബൈൻഡ് ...
#
#             director_to_rating  rating            Language  \
# 0              ആക്ഷൻ, അഡ്വഞ്ചർ  8.2/10            ഇംഗ്ലീഷ്
# 1              ആക്ഷൻ, അഡ്വഞ്ചർ  8.4/10            ഇംഗ്ലീഷ്
# 2              ആക്ഷൻ, അഡ്വഞ്ചർ  7.5/10            ഇംഗ്ലീഷ്
# 3              ആക്ഷൻ, അഡ്വഞ്ചർ  6.2/10            ഇംഗ്ലീഷ്
# 4     ഡ്രാമ, ഫാന്റസി, റൊമാൻസ്  6.6/10              കൊറിയൻ
# 5         കോമഡി, ഡ്രാമ, ഫാമിലി  7.7/10           ജാപ്പനീസ്
# 6     ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി  6.1/10            ഇംഗ്ലീഷ്
# 7                        ഡ്രാമ  7.9/10           ജാപ്പനീസ്
# 8                 കോമഡി, ഡ്രാമ  7.4/10            ഫിന്നിഷ്
# 9                 കോമഡി, ഡ്രാമ  7.6/10              ഹിന്ദി
# 10    ക്രെെം, ഡ്രാമ, മിസ്റ്ററി  6.7/10           ജാപ്പനീസ്
# 11  അഡ്വഞ്ചർ, അനിമേഷന്‍, കോമഡി  7.1/10            ഇംഗ്ലീഷ്
# 12              ഡ്രാമ, ഫാന്റസി  8.6/10              കൊറിയൻ
# 13      ക്രൈം, ഡ്രാമ, ത്രില്ലർ  8.5/10                None
# 14       ഡ്രാമ, ഹൊറർ, ത്രില്ലർ  8.5/10                None
# 15  ആക്ഷൻ, അഡ്വഞ്ചർ, അനിമേഷന്‍  7.6/10           ജാപ്പനീസ്
# 16  ഹൊറർ, മിസ്റ്ററി, ത്രില്ലർ  5.3/10             മാൻഡറിൻ
# 17                       ഡ്രാമ  7.7/10            സ്പാനിഷ്
# 18                       ഡ്രാമ  7.6/10              വോളോഫ്
# 19        അക്ഷൻ, കോമഡി, ക്രെെം  6.9/10          കാന്റോനീസ്
# 20    ക്രെെം, ഡ്രാമ, ഹിസ്റ്ററി  7.7/10            ഇംഗ്ലീഷ്
# 21     ആക്ഷൻ, ക്രെെം, ത്രില്ലർ  7.8/10              കൊറിയൻ
# 22       ഡ്രാമ, ഹൊറർ, ത്രില്ലർ  8.1/10                None
# 23      ആക്ഷൻ, അഡ്വഞ്ചർ, ഡ്രാമ  6.2/10              കൊറിയൻ
# 24  ഡ്രാമ, മിസ്റ്ററി, ത്രില്ലർ  6.3/10            ഇംഗ്ലീഷ്
# 25     ക്രെെം, ഡ്രാമ, ത്രില്ലർ  7.8/10  ഫ്രഞ്ച് & ഇംഗ്ലീഷ്
# 26       കോമഡി, ഡ്രാമ, റൊമാൻസ്  6.0/10             കൊറിയൻ
# 27             കോമഡി, റൊമാൻസ്  7.3/10             കൊറിയൻ
# 28       കോമഡി, ഡ്രാമ, റൊമാൻസ്  6.8/10              കൊറിയൻ
# 29             ബയോഗ്രഫി, ഡ്രാമ  9.2/10              ഹിന്ദി
# 30             ഡ്രാമ, റൊമാൻസ്  8.4/10            ഇംഗ്ലീഷ്
# 31      ആക്ഷൻ, അഡ്വഞ്ചർ, കോമഡി  8.4/10                None
# 32     അഡ്വഞ്ചർ, ഡ്രാമ, ഫാമിലി  6.4/10           നോർവീജിയൻ
# 33                ആക്ഷൻ, ഡ്രാമ  6.3/10              കൊറിയൻ
# 34       കോമഡി, ഡ്രാമ, ഫാന്റസി  7.0/10              കൊറിയൻ
# 35  ഡ്രാമ, മിസ്റ്ററി, ത്രില്ലർ  7.1/10            സ്പാനിഷ്
# 36  ബയോഗ്രഫി, ഡ്രാമ, ഹിസ്റ്ററി  8.4/10            ഇംഗ്ലീഷ്
# 37          ക്രൈം, ഡ്രാമ, ഹൊറർ  6.5/10            ഇംഗ്ലീഷ്
# 38         മിസ്റ്ററി, ത്രില്ലർ  7.0/10           ജാപ്പനീസ്
#
#                                Direction  \
# 0                       Steven Spielberg
# 1                       Steven Spielberg
# 2                       Steven Spielberg
# 3                       Steven Spielberg
# 4                         Lee Hyeong-min
# 5                       Takashi Yamazaki
# 6                Juan Carlos Fresnadillo
# 7                            Wim Wenders
# 8                         Aki Kaurismäki
# 9                               Amit Rai
# 10                     Kore-eda Hirokazu
# 11  Alexandre Heboyan & Benoît Philippon
# 12                         Byung-Hoon Ha
# 13                                  None
# 14                                  None
# 15                        Hayao Miyazaki
# 16                            Lester Hsi
# 17                        Alfonso Cuarón
# 18                        Matteo Garrone
# 19                             Jing Wong
# 20                       Martin Scorsese
# 21                       Jeong-Yeol Choi
# 22                                  None
# 23                      Heo Myeong Haeng
# 24                       John McNaughton
# 25                         Justine Triet
# 26                          Tae-yun Yoon
# 27                         Sang-Yeob Lee
# 28                          Kyu-dong Min
# 29                    Vidhu Vinod Chopra
# 30   Lenny Abrahamson & Hettie Macdonald
# 31                                  None
# 32                     Johanne Helgeland
# 33                         Seung-wan Ryu
# 34                           Ma Dae-Yoon
# 35                           Oriol Paulo
# 36                     Christopher Nolan
# 37                       Kenneth Branagh
# 38                       Katsuo Fukuzawa
#
#                                       Translation Director
# 0                                  വിഷ്ണു പ്രസാദ്     None
# 1                                  വിഷ്ണു പ്രസാദ്     None
# 2                                  വിഷ്ണു പ്രസാദ്     None
# 3                                  വിഷ്ണു പ്രസാദ്     None
# 4                                  അരവിന്ദ് കുമാർ     None
# 5                        സുബീഷ് ചിറ്റാരിപ്പറമ്പ്.     None
# 6                                   ഗിരി പി. എസ്.     None
# 7                           എല്‍വിന്‍ ജോണ്‍ പോള്‍     None
# 8                           എല്‍വിന്‍ ജോണ്‍ പോള്‍     None
# 9                                     സജിൻ.എം.എസ്     None
# 10                                    വിഷ്ണു ഷാജി     None
# 11                            ജിതിൻ ജേക്കബ് കോശി      None
# 12               സജിത്ത് ടി. എസ് & അരവിന്ദ് കുമാർ     None
# 13                             ഫഹദ് അബ്‍ദുൽ മജീദ്     None
# 14                                  ഗിരി പി. എസ്.     None
# 15                          എല്‍വിന്‍ ജോണ്‍ പോള്‍     None
# 16                                      സാരംഗ് പി     None
# 17                                 വിഷ്ണു പ്രസാദ്     None
# 18                                മുജീബ് സി പി വൈ     None
# 19                          എല്‍വിന്‍ ജോണ്‍ പോള്‍     None
# 20                                     വിഷ് ആസാദ്     None
# 21                                 അരവിന്ദ് കുമാർ     None
# 22                                  ഗിരി പി. എസ്.     None
# 23                                     തൗഫീക്ക് എ     None
# 24                                  അഭിഷേക് പി യു     None
# 25                                       ഡോ. ജമാൽ     None
# 26                                സജിത്ത് ടി. എസ്     None
# 27  അരുൺ അശോകൻ, ശ്രുതി രഞ്ജിത്ത് & അരവിന്ദ് കുമാർ     None
# 28                                 അരവിന്ദ് കുമാർ     None
# 29                       വിഷ് ആസാദ് & സജിൻ.എം.എസ്     None
# 30                          അരുൺ അശോകൻ & ഉദയകൃഷ്ണ     None
# 31                                 വിഷ്ണു പ്രസാദ്     None
# 32                                       ഡോ. ജമാൽ     None
# 33                                     തൗഫീക്ക് എ     None
# 34                                സജിത്ത് ടി. എസ്     None
# 35                                    വിഷ്ണു ഷാജി     None
# 36                          എല്‍വിന്‍ ജോണ്‍ പോള്‍     None
# 37                             ഫഹദ് അബ്‍ദുൽ മജീദ്     None
# 38                                      ആസിഫ് ആസി     None

# %%
import requests
from bs4 import BeautifulSoup

# URL to scrape
url = "https://malayalamsubtitles.org/languages/japanese/perfect-days-2023/"

# Send GET request to the URL
response = requests.get(url)

# Parse HTML content
soup = BeautifulSoup(response.content, "html.parser")

# Find the tag with class="entry-categories"
entry_categories_tag = soup.find("span", class_="entry-categories")

# Find the tag with class="entry-tags"
entry_tags_tag = soup.find("span", class_="entry-tags")

# Extract content within the entry-categories tag
if entry_categories_tag:
    entry_categories_content = entry_categories_tag.text.strip()
    print("Content within the entry-categories tag:")
    print(entry_categories_content)
else:
    print("No content found within the entry-categories tag.")

# Extract content within the entry-tags tag
if entry_tags_tag:
    entry_tags_content = entry_tags_tag.text.strip()
    print("\nContent within the entry-tags tag:")
    print(entry_tags_content)
else:
    print("No content found within the entry-tags tag.")
# Out:
# Content within the entry-categories tag:
# Filed Under: Drama, Japanese, Oscar Fest 2024
#
# Content within the entry-tags tag:
# Tagged: Elvin John Paul

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from IPython.display import display

# Define the base URL of the website to scrape
base_url = 'https://malayalamsubtitles.org/page/'

# Define the number of pages to scrape
num_pages = 2

# Initialize a list to store all scraped data
all_data = []

# Function to extract parts of the text using regular expressions
def extract_parts(text):
    match = re.match(r'(.*?)\sഭാഷ\s(.*?)\sസംവിധാനം\s(.*?)\sപരിഭാഷ\s(.*?)\sജോണർ\s(.*)', text)
    if match:
        return match.groups()
    else:
        return (None, None, None, None, None)

# Function to extract rating
def extract_rating(text):
    match = re.search(r'(\d\.\d)/10', text)
    if match:
        return match.group(1) + "/10"
    else:
        return None

# Function to extract director name
def extract_director(text):
    match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
    if match:
        return match.group(1)
    else:
        return None

# Retry logic
retry_strategy = Retry(
    total=3,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    method_whitelist=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f'{base_url}{page_number}/'
    
    # Send a GET request to the URL with retry logic
    with requests.Session() as session:
        session.mount("https://", adapter)
        try:
            response = session.get(url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Failed to retrieve the webpage: {url}")
            continue
    
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link with retry logic
        with requests.Session() as session:
            session.mount("https://", adapter)
            try:
                sub_response = session.get(link)
                sub_response.raise_for_status()
            except requests.exceptions.RequestException as e:
                print(f"Failed to retrieve content from {link}")
                continue
        
        # Parse the HTML content of the subpage
        sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
        
        # Find the tag containing the specified class attribute
        download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
        
        # Extract data-downloadurl attribute from each tag
        for download_link in download_links:
            data_downloadurl = download_link.get('data-downloadurl')
            
            # Find the meta tags with property="og:description", "og:image", and "og:title"
            og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
            og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
            og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None
            
            # Find the meta tag with name="author"
            author_tag = sub_soup.find('meta', {'name': 'author'})
            author_content = author_tag['content'] if author_tag else None
            
            # Find the figure tag with class="alignleft size-large"
            figure_tag = sub_soup.find('figure', class_='alignleft size-large')
            figure_href = figure_tag.find('a')['href'] if figure_tag else None

            # Find the tags with class="entry-categories" and "entry-tags"
            entry_categories_tag = sub_soup.find('span', class_='entry-categories')
            entry_categories_content = entry_categories_tag.text.strip() if entry_categories_tag else None
            
            entry_tags_tag = sub_soup.find('span', class_='entry-tags')
            entry_tags_content = entry_tags_tag.text.strip() if entry_tags_tag else None

            # Append the extracted data to the all_data list
            all_data.append((link, data_downloadurl, og_description, og_image, og_title, author_content, figure_href, entry_categories_content, entry_tags_content))

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, og:title, author, figure_href, entry-categories, and entry-tags attributes
df = pd.DataFrame(all_data, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title', 'author', 'figure_href', 'entry-categories', 'entry-tags'])

# Add the 'director_to_rating' column
df['director_to_rating'] = df['og:description'].apply(extract_director)

# Add the 'rating' column
df['rating'] = df['og:description'].apply(extract_rating)

# Apply the function to the 'og:description' column and expand it into separate columns
df[['Column1', 'Column2', 'Column3', 'Column4', 'Column5']] = df['og:description'].apply(lambda x: pd.Series(extract_parts(x)))

# Assuming df is your DataFrame and you want to remove the 'Column5' column
df.drop(columns=['Column5'], inplace=True)

# Display the DataFrame
print(df)
# Out:
# /var/folders/0j/k_c7797n13v3f73bfmht7jym0000gn/T/ipykernel_19145/2137452525.py:43: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(
#                                                   URL  \
# 0   https://malayalamsubtitles.org/languages/engli...
# 1   https://malayalamsubtitles.org/languages/engli...
# 2   https://malayalamsubtitles.org/languages/engli...
# 3   https://malayalamsubtitles.org/languages/engli...
# 4   https://malayalamsubtitles.org/languages/korea...
# 5   https://malayalamsubtitles.org/languages/japan...
# 6   https://malayalamsubtitles.org/languages/engli...
# 7   https://malayalamsubtitles.org/languages/japan...
# 8   https://malayalamsubtitles.org/languages/finni...
# 9   https://malayalamsubtitles.org/languages/hindi...
# 10  https://malayalamsubtitles.org/languages/japan...
# 11  https://malayalamsubtitles.org/languages/frenc...
# 12  https://malayalamsubtitles.org/languages/korea...
# 13  https://malayalamsubtitles.org/languages/engli...
# 14  https://malayalamsubtitles.org/languages/engli...
# 15  https://malayalamsubtitles.org/languages/japan...
#
#                                      data-downloadurl  \
# 0   https://malayalamsubtitles.org/download/indian...
# 1   https://malayalamsubtitles.org/download/indian...
# 2   https://malayalamsubtitles.org/download/indian...
# 3   https://malayalamsubtitles.org/download/indian...
# 4   https://malayalamsubtitles.org/download/postma...
# 5   https://malayalamsubtitles.org/download/always...
# 6   https://malayalamsubtitles.org/download/damsel...
# 7   https://malayalamsubtitles.org/download/perfec...
# 8   https://malayalamsubtitles.org/download/fallen...
# 9   https://malayalamsubtitles.org/download/omg-2-...
# 10  https://malayalamsubtitles.org/download/the-th...
# 11  https://malayalamsubtitles.org/download/mune-g...
# 12  https://malayalamsubtitles.org/download/deaths...
# 13  https://malayalamsubtitles.org/download/ozark-...
# 14  https://malayalamsubtitles.org/download/the-wa...
# 15  https://malayalamsubtitles.org/download/lupin-...
#
#                                        og:description  \
# 0   എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 1   എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 2   എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 3   എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...
# 4   എംസോൺ റിലീസ് – 3331 ഭാഷ കൊറിയൻ സംവിധാനം Lee Hy...
# 5   എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Taka...
# 6   എംസോൺ റിലീസ് – 3330 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Juan...
# 7   എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ...
# 8   എംസോൺ റിലീസ് – 3327 ഭാഷ ഫിന്നിഷ് സംവിധാനം Aki ...
# 9   എംസോൺ റിലീസ് – 3322 ഭാഷ ഹിന്ദി സംവിധാനം Amit R...
# 10  എംസോൺ റിലീസ് – 3328 ഭാഷ ജാപ്പനീസ് സംവിധാനം Kor...
# 11  എംസോൺ റിലീസ് – 3323 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Alex...
# 12  എംസോൺ റിലീസ് – 3324 ഭാഷ കൊറിയൻ സംവിധാനം Byung-...
# 13  എംസോൺ റിലീസ് – 3299 ഭാഷ ഇംഗ്ലീഷ് നിർമ്മാണം MRC...
# 14  എംസോൺ റിലീസ് – 3326 Episodes 01-05 / എപ്പിസോഡ്...
# 15  എംസോൺ റിലീസ് – 3325 MSONE GOLD RELEASE ഭാഷ ജാപ...
#
#                                              og:image  \
# 0   https://malayalamsubtitles.org/wp-content/uplo...
# 1   https://malayalamsubtitles.org/wp-content/uplo...
# 2   https://malayalamsubtitles.org/wp-content/uplo...
# 3   https://malayalamsubtitles.org/wp-content/uplo...
# 4   https://malayalamsubtitles.org/wp-content/uplo...
# 5   https://malayalamsubtitles.org/wp-content/uplo...
# 6   https://malayalamsubtitles.org/wp-content/uplo...
# 7   https://malayalamsubtitles.org/wp-content/uplo...
ഡ്രാമ, ഫാന്റസി, റൊമാൻസ്  6.6/10
# 5     Tagged: Subeesh Chittariparamb        കോമഡി, ഡ്രാമ, ഫാമിലി  7.7/10
# 6                    Tagged: Giri PS    ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി  6.1/10
# 7            Tagged: Elvin John Paul                       ഡ്രാമ  7.9/10
# 8            Tagged: Elvin John Paul                കോമഡി, ഡ്രാമ  7.4/10
# 9                   Tagged: Sajin MS                കോമഡി, ഡ്രാമ  7.6/10
# 10              Tagged: Vishnu Shaji    ക്രെെം, ഡ്രാമ, മിസ്റ്ററി  6.7/10
# 11        Tagged: Jithin Jacob Koshy  അഡ്വഞ്ചർ, അനിമേഷന്‍, കോമഡി  7.1/10
# 12  Tagged: Aravind Kumar, Sajith TS              ഡ്രാമ, ഫാന്റസി  8.6/10
# 13        Tagged: Fahad Abdul Majeed      ക്രൈം, ഡ്രാമ, ത്രില്ലർ  8.5/10
# 14                   Tagged: Giri PS       ഡ്രാമ, ഹൊറർ, ത്രില്ലർ  8.5/10
# 15           Tagged: Elvin John Paul  ആക്ഷൻ, അഡ്വഞ്ചർ, അനിമേഷന്‍  7.6/10
#
#                                           Column1    Column2  \
# 0           എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE   ഇംഗ്ലീഷ്
# 1           എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE   ഇംഗ്ലീഷ്
# 2           എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE   ഇംഗ്ലീഷ്
# 3                              എംസോൺ റിലീസ് – 217   ഇംഗ്ലീഷ്
# 4                             എംസോൺ റിലീസ് – 3331     കൊറിയൻ
# 5                              എംസോൺ റിലീസ് – 887  ജാപ്പനീസ്
# 6                             എംസോൺ റിലീസ് – 3330   ഇംഗ്ലീഷ്
# 7   എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09  ജാപ്പനീസ്
# 8                             എംസോൺ റിലീസ് – 3327   ഫിന്നിഷ്
# 9                             എംസോൺ റിലീസ് – 3322     ഹിന്ദി
# 10                            എംസോൺ റിലീസ് – 3328  ജാപ്പനീസ്
# 11                            എംസോൺ റിലീസ് – 3323   ഇംഗ്ലീഷ്
# 12                            എംസോൺ റിലീസ് – 3324     കൊറിയൻ
# 13                                           None       None
# 14                                           None       None
# 15         എംസോൺ റിലീസ് – 3325 MSONE GOLD RELEASE  ജാപ്പനീസ്
#
#                                  Column3                           Column4
# 0                       Steven Spielberg                    വിഷ്ണു പ്രസാദ്
# 1                       Steven Spielberg                    വിഷ്ണു പ്രസാദ്
# 2                       Steven Spielberg                    വിഷ്ണു പ്രസാദ്
# 3                       Steven Spielberg                    വിഷ്ണു പ്രസാദ്
# 4                         Lee Hyeong-min                    അരവിന്ദ് കുമാർ
# 5                       Takashi Yamazaki          സുബീഷ് ചിറ്റാരിപ്പറമ്പ്.
# 6                Juan Carlos Fresnadillo                     ഗിരി പി. എസ്.
# 7                            Wim Wenders             എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 8                         Aki Kaurismäki             എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 9                               Amit Rai                       സജിൻ.എം.എസ്
# 10                     Kore-eda Hirokazu                       വിഷ്ണു ഷാജി
# 11  Alexandre Heboyan & Benoît Philippon               ജിതിൻ ജേക്കബ് കോശി
# 12                         Byung-Hoon Ha  സജിത്ത് ടി. എസ് & അരവിന്ദ് കുമാർ
# 13                                  None                              None
# 14                                  None                              None
# 15                        Hayao Miyazaki             എല്‍വിന്‍ ജോണ്‍ പോള്‍
