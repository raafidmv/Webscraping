# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from IPython.display import display

# Define the base URL of the website to scrape
base_url = 'https://malayalamsubtitles.org/page/'

# Define the number of pages to scrape
num_pages = 2

# Initialize a list to store all scraped data
all_data = []

# Function to extract parts of the text using regular expressions
def extract_parts(text):
    match = re.match(r'(.*?)\sഭാഷ\s(.*?)\sസംവിധാനം\s(.*?)\sപരിഭാഷ\s(.*?)\sജോണർ\s(.*)', text)
    if match:
        return match.groups()
    else:
        return (None, None, None, None, None)

# Function to extract rating
def extract_rating(text):
    match = re.search(r'(\d\.\d)/10', text)
    if match:
        return match.group(1) + "/10"
    else:
        return None

# Function to extract director name
def extract_director(text):
    match = re.search(r'ജോണർ\s(.*)\s\d\.\d/10', text)
    if match:
        return match.group(1)
    else:
        return None

# Retry logic
retry_strategy = Retry(
    total=3,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    method_whitelist=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)

# Loop through each page
for page_number in range(1, num_pages + 1):
    # Construct the URL for the current page
    url = f'{base_url}{page_number}/'
    
    # Send a GET request to the URL with retry logic
    with requests.Session() as session:
        session.mount("https://", adapter)
        try:
            response = session.get(url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Failed to retrieve the webpage: {url}")
            continue
    
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract specific information from the page
    # For example, let's extract all the links on the page
    links = soup.find_all('a')
    
    # Set to store unique links
    unique_links = set()
    
    # Filter and add unique links that start with 'https://malayalamsubtitles.org/languages'
    for link in links:
        href = link.get('href', '')
        if href.startswith('https://malayalamsubtitles.org/languages'):
            unique_links.add(href)
    
    # Iterate through unique links and scrape desired information
    for link in unique_links:
        # Send a GET request to the link with retry logic
        with requests.Session() as session:
            session.mount("https://", adapter)
            try:
                sub_response = session.get(link)
                sub_response.raise_for_status()
            except requests.exceptions.RequestException as e:
                print(f"Failed to retrieve content from {link}")
                continue
        
        # Parse the HTML content of the subpage
        sub_soup = BeautifulSoup(sub_response.content, 'html.parser')
        
        # Find the tag containing the specified class attribute
        download_links = sub_soup.find_all('a', class_='wpdm-download-link download-on-click btn btn-primary', rel='nofollow', href='#')
        
        # Extract data-downloadurl attribute from each tag
        for download_link in download_links:
            data_downloadurl = download_link.get('data-downloadurl')
            
            # Find the meta tags with property="og:description", "og:image", and "og:title"
            og_description = sub_soup.find('meta', property='og:description').get('content', '') if sub_soup.find('meta', property='og:description') else None
            og_image = sub_soup.find('meta', property='og:image').get('content', '') if sub_soup.find('meta', property='og:image') else None
            og_title = sub_soup.find('meta', property='og:title').get('content', '') if sub_soup.find('meta', property='og:title') else None

             # Find the figure tag with class="alignleft size-large"
            figure_tag = sub_soup.find('figure', class_='alignleft size-large')
            figure_href = figure_tag.find('a')['href'] if figure_tag else None
          
        # Find the tags with class="entry-categories" and "entry-tags"
            entry_categories_tag = sub_soup.find('span', class_='entry-categories')
            entry_categories_content = entry_categories_tag.text.strip() if entry_categories_tag else None
            
            entry_tags_tag = sub_soup.find('span', class_='entry-tags')
            entry_tags_content = entry_tags_tag.text.strip() if entry_tags_tag else None

            # Append the extracted data to the all_data list
            all_data.append((link, data_downloadurl, og_description, og_image, og_title, figure_href, entry_categories_content, entry_tags_content))

# Create a DataFrame with URL, data-downloadurl, og:description, og:image, og:title, author, figure_href, entry-categories, and entry-tags attributes
df = pd.DataFrame(all_data, columns=['URL', 'data-downloadurl', 'og:description', 'og:image', 'og:title', 'figure_href', 'entry-categories', 'entry-tags'])


# Add the 'director_to_rating' column
df['director_to_rating'] = df['og:description'].apply(extract_director)

# Add the 'rating' column
df['rating'] = df['og:description'].apply(extract_rating)

# Apply the function to the 'og:description' column and expand it into separate columns
df[['Column1', 'Column2', 'Column3', 'Column4', 'Column5']] = df['og:description'].apply(lambda x: pd.Series(extract_parts(x)))

# Assuming df is your DataFrame and you want to remove the 'Column5' column
df.drop(columns=['Column5'], inplace=True)

# display(df)
# print(df.columns)
# # Save the DataFrame as an Excel file
# excel_file_path = 'malayalamsubtitles_data.xlsx'
# df.to_excel(excel_file_path, index=False)
# print("Data has been saved to 'scraped_data.xlsx'")

#print(df.columns)
# Rename duplicate columns to make them unique
df = df.rename(columns={'Column1': 'Column1_new', 'Column2': 'Column2_new', 'Column3': 'Column3_new', 'Column4': 'Column4_new'})

# Define the desired column order
desired_order = ['Column1_new', 'og:title', 'Column2_new', 'Column3_new', 'entry-tags', 'Column4_new', 'entry-categories', 'URL', 'og:image', 'figure_href', 'rating', 'director_to_rating', 'data-downloadurl', 'og:description']

# Reindex columns
df = df.reindex(columns=desired_order)

# Rename columns
df = df.rename(columns={'Column1_new': 'release_no', 'og:title': 'title', 'Column2_new': 'language', 'Column3_new': 'director', 'entry-tags': 'author', 'Column4_new': 'translated_by', 'entry-categories': 'tags', 'URL': 'website_link', 'og:image': 'poster', 'figure_href': 'imdb', 'rating': 'rating', 'director_to_rating': 'genre', 'data-downloadurl': 'download_link', 'og:description': 'description'})

# Display the DataFrame
# display(df)



# Split the 'title' column into two columns
df[['title1', 'title2']] = df['title'].str.split(' / ', expand=True)

# Remove the data after the term '(' in the 'title' column
df['title2'] = df['title2'].str.split('(', n=1).str[0]

# Remove the end part '- എംസോൺ' from every row in the 'title' column
df['title'] = df['title'].str.replace(' - എംസോൺ$', '')

# Remove the term 'എംസോൺ റിലീസ് – ' from every row in the 'release_num' column
df['release_no'] = df['release_no'].str.replace('എംസോൺ റിലീസ് – ', '')

# Extract the data within brackets and put it into a new column
df['year'] = df['title'].str.extract(r'\((\d{4})\)')


# Extract the term after 'languages/' up to the next '/'
df['lang'] = df['website_link'].str.extract(r'/languages/([^/]+)/')

# Remove the word "Tagged: " from the 'entry-tags' column
df['author'] = df['author'].str.replace('Tagged: ', '')

# Remove the word "Tagged: " from the 'entry-tags' column
df['tags'] = df['tags'].str.replace('Filed Under: ', '')



# Rearrange the last 4 columns in front of the second column
df.insert(1, 'title1', df.pop('title1'))
df.insert(2, 'title2', df.pop('title2'))
df.insert(3, 'year', df.pop('year'))
df.insert(4, 'lang', df.pop('lang'))


# Display the DataFrame
display(df)
# Save the DataFrame as an Excel file
excel_file_path = 'malayalamsubles_data.xlsx'
df.to_excel(excel_file_path, index=False)
print("Data has been saved to 'scraped_data.xlsx'")
# Out:
# /Users/raafid_mv/Documents/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /var/folders/0j/k_c7797n13v3f73bfmht7jym0000gn/T/ipykernel_21123/1123080982.py:43: DeprecationWarning: Using 'method_whitelist' with Retry is deprecated and will be removed in v2.0. Use 'allowed_methods' instead
#   retry_strategy = Retry(
#                         release_no  \
# 0                             3330
# 1                              887
# 2   3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09
# 3                              217
# 4           216 MSONE GOLD RELEASE
# 5                             3331
# 6           215 MSONE GOLD RELEASE
# 7           213 MSONE GOLD RELEASE
# 8          3325 MSONE GOLD RELEASE
# 9                             3324
# 10                            None
# 11                            3322
# 12                            3323
# 13                            3328
# 14                            3327
# 15                            None
#
#                                                title1  \
# 0                                              Damsel
# 1                      Always: Sunset on Third Street
# 2                                        Perfect Days
# 3   Indiana Jones and the Kingdom of the Crystal S...
# 4                  Indiana Jones and the Last Crusade
# 5                                   Postman to Heaven
# 6                Indiana Jones and the Temple of Doom
# 7       Indiana Jones and the Raiders of the Lost Ark
# 8                 Lupin III: The Castle of Cagliostro
# 9                              Death's Game [K-Drama]
# 10                                     Ozark Season 4
# 11                                              OMG 2
# 12                         Mune: Guardian of the Moon
# 13                                   The Third Murder
# 14                                      Fallen Leaves
# 15       The Walking Dead: The Ones Who Live Season 1
#
#                                                title2  year  \
# 0                                             ഡാംസെൽ   2024
# 1                ഓൾവേസ്: സൺസെറ്റ് ഓൺ തേഡ് സ്ട്രീറ്റ്   2005
# 2                                  പെർഫക്റ്റ് ഡേയ്സ്   2023
# 3   ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ കിങ്ഡം ഓഫ് ദ ക്രിസ്റ്റൽ സ...  2008
# 4             ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ ലാസ്റ്റ് ക്രൂസേഡ്   1989
# 5                                പോസ്റ്റ്മാൻ ടു ഹെവൻ   2009
# 6               ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ ടെമ്പിൾ ഓഫ് ഡൂം   1984
# 7   ഇൻഡിയാന ജോൺസ് ആൻഡ് ദ റെയ്ഡേഴ്സ് ഓഫ് ദ ലോസ്റ്റ്...  1981
# 8          ലൂപാന്‍ III: ദ കാസില്‍ ഓഫ് കാഗ്ലിയോസ്ട്രോ   1979
# 9                          ഡെത്ത്സ് ഗെയിം [കെ-ഡ്രാമ]   2023
# 10                                     ഒസാർക് സീസൺ 4   2022
# 11                                         ഓ എം ജി 2   2023
# 12                          മ്യൂൺ: ഗാർഡിയൻ ഓഫ് ദ മൂൺ   2014
# 13                                       ദ തേഡ് മർഡർ   2017
# 14                                       ഫോളൻ ലീവ്സ്   2023
# 15            ദ വാക്കിങ് ഡെഡ്: ദ വൺസ് ഹു ലിവ് സീസൺ 1   2024
#
#                  lang                                              title  \
# 0             english                     Damsel / ഡാംസെൽ (2024) - എംസോൺ
# 1            japanese  Always: Sunset on Third Street / ഓൾവേസ്: സൺസെറ...
# 2            japanese    Perfect Days / പെർഫക്റ്റ് ഡേയ്സ് (2023) - എംസോൺ
# 3             english  Indiana Jones and the Kingdom of the Crystal S...
# 4             english  Indiana Jones and the Last Crusade / ഇൻഡിയാന ജ...
# 5              korean  Postman to Heaven / പോസ്റ്റ്മാൻ ടു ഹെവൻ (2009)...
# 6             english  Indiana Jones and the Temple of Doom / ഇൻഡിയാന...
# 7             english  Indiana Jones and the Raiders of the Lost Ark ...
# 8            japanese  Lupin III: The Castle of Cagliostro / ലൂപാന്‍ ...
# 9              korean  Death's Game [K-Drama] / ഡെത്ത്സ് ഗെയിം [കെ-ഡ്...
# 10            english      Ozark Season 4 / ഒസാർക് സീസൺ 4 (2022) - എംസോൺ
# 11              hindi                   OMG 2 / ഓ എം ജി 2 (2023) - എംസോൺ
# 12             french  Mune: Guardian of the Moon / മ്യൂൺ: ഗാർഡിയൻ ഓഫ...
# 13           japanese      The Third Murder / ദ തേഡ് മർഡർ (2017) - എംസോൺ
# 14  finnish-languages         Fallen Leaves / ഫോളൻ ലീവ്സ് (2023) - എംസോൺ
# 15            english  The Walking Dead: The Ones Who Live Season 1 /...
#
#      language                              director                    author  \
# 0    ഇംഗ്ലീഷ്               Juan Carlos Fresnadillo                   Giri PS
# 1   ജാപ്പനീസ്                      Takashi Yamazaki    Subeesh Chittariparamb
# 2   ജാപ്പനീസ്                           Wim Wenders           Elvin John Paul
# 3    ഇംഗ്ലീഷ്                      Steven Spielberg             Vishnu Prasad
# 4    ഇംഗ്ലീഷ്                      Steven Spielberg             Vishnu Prasad
# 5      കൊറിയൻ                        Lee Hyeong-min             Aravind Kumar
# 6    ഇംഗ്ലീഷ്                      Steven Spielberg             Vishnu Prasad
# 7    ഇംഗ്ലീഷ്                      Steven Spielberg             Vishnu Prasad
# 8   ജാപ്പനീസ്                        Hayao Miyazaki           Elvin John Paul
# 9      കൊറിയൻ                         Byung-Hoon Ha  Aravind Kumar, Sajith TS
# 10       None                                  None        Fahad Abdul Majeed
# 11     ഹിന്ദി                              Amit Rai                  Sajin MS
# 12   ഇംഗ്ലീഷ്  Alexandre Heboyan & Benoît Philippon        Jithin Jacob Koshy
# 13  ജാപ്പനീസ്                     Kore-eda Hirokazu              Vishnu Shaji
# 14   ഫിന്നിഷ്                        Aki Kaurismäki           Elvin John Paul
# 15       None                                  None                   Giri PS
#
#                        translated_by  \
# 0                      ഗിരി പി. എസ്.
# 1           സുബീഷ് ചിറ്റാരിപ്പറമ്പ്.
# 2              എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 3                     വിഷ്ണു പ്രസാദ്
# 4                     വിഷ്ണു പ്രസാദ്
# 5                     അരവിന്ദ് കുമാർ
# 6                     വിഷ്ണു പ്രസാദ്
# 7                     വിഷ്ണു പ്രസാദ്
# 8              എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 9   സജിത്ത് ടി. എസ് & അരവിന്ദ് കുമാർ
# 10                              None
# 11                       സജിൻ.എം.എസ്
# 12               ജിതിൻ ജേക്കബ് കോശി
# 13                       വിഷ്ണു ഷാജി
# 14             എല്‍വിന്‍ ജോണ്‍ പോള്‍
# 15                              None
#
#                                                  tags  \
# 0                 Action, Adventure, English, Fantasy
# 1                     Comedy, Drama, Family, Japanese
# 2                    Drama, Japanese, Oscar Fest 2024
# 3                          Action, Adventure, English
# 4              Action, Adventure, English, Msone Gold
# 5                     Drama, Fantasy, Korean, Romance
# 6              Action, Adventure, English, Msone Gold
# 7              Action, Adventure, English, Msone Gold
# 8   Action, Adventure, Animation, Japanese, Msone ...
# 9                  Drama, Fantasy, Korean, Web Series
# 10        Crime, Drama, English, Thriller, Web Series
# 11                               Comedy, Drama, Hindi
# 12               Adventure, Animation, Comedy, French
# 13                    Crime, Drama, Japanese, Mystery
# 14                             Comedy, Drama, Finnish
# 15       Drama, English, Horror, Thriller, Web Series
#
#                                          website_link  \
# 0   https://malayalamsubtitles.org/languages/engli...
# 1   https://malayalamsubtitles.org/languages/japan...
# 2   https://malayalamsubtitles.org/languages/japan...
# 3   https://malayalamsubtitles.org/languages/engli...
# 4   https://malayalamsubtitles.org/languages/engli...
# 5   https://malayalamsubtitles.org/languages/korea...
# 6   https://malayalamsubtitles.org/languages/engli...
# 7   https://malayalamsubtitles.org/languages/engli...
# 8   https://malayalamsubtitles.org/languages/japan...
# 9   https://malayalamsubtitles.org/languages/korea...
# 10  https://malayalamsubtitles.org/languages/engli...
# 11  https://malayalamsubtitles.org/languages/hindi...
# 12  https://malayalamsubtitles.org/languages/frenc...
# 13  https://malayalamsubtitles.org/languages/japan...
# 14  https://malayalamsubtitles.org/languages/finni...
# 15  https://malayalamsubtitles.org/languages/engli...
#
#                                                poster  \
# 0   https://malayalamsubtitles.org/wp-content/uplo...
# 1   https://malayalamsubtitles.org/wp-content/uplo...
# 2   https://malayalamsubtitles.org/wp-content/uplo...
# 3   https://malayalamsubtitles.org/wp-content/uplo...
# 4   https://malayalamsubtitles.org/wp-content/uplo...
# 5   https://malayalamsubtitles.org/wp-content/uplo...
# 6   https://malayalamsubtitles.org/wp-content/uplo...
# 7   https://malayalamsubtitles.org/wp-content/uplo...
# 8   https://malayalamsubtitles.org/wp-content/uplo...
# 9   https://malayalamsubtitles.org/wp-content/uplo...
# 10  https://malayalamsubtitles.org/wp-content/uplo...
# 11  https://malayalamsubtitles.org/wp-content/uplo...
# 12  https://malayalamsubtitles.org/wp-content/uplo...
# 13  https://malayalamsubtitles.org/wp-content/uplo...
# 14  https://malayalamsubtitles.org/wp-content/uplo...
# 15  https://malayalamsubtitles.org/wp-content/uplo...
#
#                                       imdb  rating  \
# 0   https://www.imdb.com/title/tt13452446/  6.1/10
# 1    https://www.imdb.com/title/tt0488870/  7.7/10
# 2   https://www.imdb.com/title/tt27503384/  7.9/10
# 3    https://www.imdb.com/title/tt0367882/  6.2/10
# 4    https://www.imdb.com/title/tt0097576/  8.2/10
# 5    https://www.imdb.com/title/tt2012626/  6.6/10
# 6    https://www.imdb.com/title/tt0087469/  7.5/10
# 7    https://www.imdb.com/title/tt0082971/  8.4/10
# 8    https://www.imdb.com/title/tt0079833/  7.6/10
# 9   https://www.imdb.com/title/tt26225038/  8.6/10
# 10   https://www.imdb.com/title/tt5071412/  8.5/10
# 11  https://www.imdb.com/title/tt15732324/  7.6/10
# 12   https://www.imdb.com/title/tt3858372/  7.1/10
# 13   https://www.imdb.com/title/tt6410564/  6.7/10
# 14  https://www.imdb.com/title/tt21027780/  7.4/10
# 15   https://www.imdb.com/title/tt9859436/  8.5/10
#
#                          genre  \
# 0     ആക്ഷൻ, അഡ്വഞ്ചർ, ഫാന്റസി
# 1         കോമഡി, ഡ്രാമ, ഫാമിലി
# 2                        ഡ്രാമ
# 3              ആക്ഷൻ, അഡ്വഞ്ചർ
# 4              ആക്ഷൻ, അഡ്വഞ്ചർ
# 5     ഡ്രാമ, ഫാന്റസി, റൊമാൻസ്
# 6              ആക്ഷൻ, അഡ്വഞ്ചർ
# 7              ആക്ഷൻ, അഡ്വഞ്ചർ
# 8   ആക്ഷൻ, അഡ്വഞ്ചർ, അനിമേഷന്‍
# 9               ഡ്രാമ, ഫാന്റസി
# 10      ക്രൈം, ഡ്രാമ, ത്രില്ലർ
# 11                കോമഡി, ഡ്രാമ
# 12  അഡ്വഞ്ചർ, അനിമേഷന്‍, കോമഡി
# 13    ക്രെെം, ഡ്രാമ, മിസ്റ്ററി
# 14                കോമഡി, ഡ്രാമ
# 15       ഡ്രാമ, ഹൊറർ, ത്രില്ലർ
#
#                                         download_link  \
# 0   https://malayalamsubtitles.org/download/damsel...
# 1   https://malayalamsubtitles.org/download/always...
# 2   https://malayalamsubtitles.org/download/perfec...
# 3   https://malayalamsubtitles.org/download/indian...
# 4   https://malayalamsubtitles.org/download/indian...
# 5   https://malayalamsubtitles.org/download/postma...
# 6   https://malayalamsubtitles.org/download/indian...
# 7   https://malayalamsubtitles.org/download/indian...
# 8   https://malayalamsubtitles.org/download/lupin-...
# 9   https://malayalamsubtitles.org/download/deaths...
# 10  https://malayalamsubtitles.org/download/ozark-...
# 11  https://malayalamsubtitles.org/download/omg-2-...
# 12  https://malayalamsubtitles.org/download/mune-g...
# 13  https://malayalamsubtitles.org/download/the-th...
# 14  https://malayalamsubtitles.org/download/fallen...
# 15  https://malayalamsubtitles.org/download/the-wa...
#
#                                           description
# 0   എംസോൺ റിലീസ് – 3330 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Juan...
# 1   എംസോൺ റിലീസ് – 887 ഭാഷ ജാപ്പനീസ് സംവിധാനം Taka...
# 2   എംസോൺ റിലീസ് – 3329 ഓസ്കാർ ഫെസ്റ്റ് 2024 – 09 ...
# 3   എംസോൺ റിലീസ് – 217 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Steve...
# 4   എംസോൺ റിലീസ് – 216 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 5   എംസോൺ റിലീസ് – 3331 ഭാഷ കൊറിയൻ സംവിധാനം Lee Hy...
# 6   എംസോൺ റിലീസ് – 215 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 7   എംസോൺ റിലീസ് – 213 MSONE GOLD RELEASE ഭാഷ ഇംഗ്...
# 8   എംസോൺ റിലീസ് – 3325 MSONE GOLD RELEASE ഭാഷ ജാപ...
# 9   എംസോൺ റിലീസ് – 3324 ഭാഷ കൊറിയൻ സംവിധാനം Byung-...
# 10  എംസോൺ റിലീസ് – 3299 ഭാഷ ഇംഗ്ലീഷ് നിർമ്മാണം MRC...
# 11  എംസോൺ റിലീസ് – 3322 ഭാഷ ഹിന്ദി സംവിധാനം Amit R...
# 12  എംസോൺ റിലീസ് – 3323 ഭാഷ ഇംഗ്ലീഷ് സംവിധാനം Alex...
# 13  എംസോൺ റിലീസ് – 3328 ഭാഷ ജാപ്പനീസ് സംവിധാനം Kor...
# 14  എംസോൺ റിലീസ് – 3327 ഭാഷ ഫിന്നിഷ് സംവിധാനം Aki ...
# 15  എംസോൺ റിലീസ് – 3326 Episodes 01-05 / എപ്പിസോഡ്...
# Data has been saved to 'scraped_data.xlsx'
